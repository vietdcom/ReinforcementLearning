# %%
import os

import torch
import torch.nn as nn
import torch.optim as optim
import chess
import random

class ChessBoard:
    def __init__(self):
        self.board = chess.Board()

    def get_state(self):
        # Convert board to a numerical representation for the network
        # Example:  a simple representation, can be improved
        state = []
        for square in chess.SQUARES:
            piece = self.board.piece_at(square)
            if piece:
                value = piece.piece_type * (1 if piece.color else -1)
                state.append(value)
            else:
                state.append(0)
        return torch.tensor(state, dtype=torch.float32)

    def __str__(self):
        s = ""
        board_str = str(self.board)
        for row in board_str.split("\n"):
            s += "  " + row + "\n"
        s += "  " + "----------------\n"
        s += "   a b c d e f g h"
        return s

    def print_board(self):
        print(self)

    def copy(self):
        new_board = ChessBoard()
        new_board.board = self.board.copy()
        return new_board

    def display(self):
        print(self)


    def get_legal_moves(self):
        return list(self.board.legal_moves)

    def make_move(self, move):
        if move.promotion is not None:
            # Pawn promotion
            promotion_piece = None
            while promotion_piece not in [chess.QUEEN, chess.ROOK, chess.BISHOP, chess.KNIGHT]:
                piece_str = input("Choose promotion piece (Q, R, B, N): ").upper()
                if piece_str == 'Q': promotion_piece = chess.QUEEN
                elif piece_str == 'R': promotion_piece = chess.ROOK
                elif piece_str == 'B': promotion_piece = chess.BISHOP
                elif piece_str == 'N': promotion_piece = chess.KNIGHT
            move.promotion = promotion_piece
        self.board.push(move) # Now push the (potentially promotion) move


    def is_game_over(self):
        return self.board.is_game_over()

    def get_result(self):
        if self.board.is_checkmate():
            return 1 if self.board.turn == chess.BLACK else -1  # 1 if white wins, -1 if black wins
        elif self.board.is_stalemate() or self.board.is_insufficient_material() or self.board.is_seventyfive_moves() or self.board.is_fivefold_repetition() or self.board.is_variant_draw():
            return 0  # Draw
        else:
            return None # Game still in progress

class ChessNet(nn.Module):
    def __init__(self):
        super(ChessNet, self).__init__()
        self.fc1 = nn.Linear(64, 128)  # Example architecture
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 1)  # Output a score for the position

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.to(self.device)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.tanh(self.fc3(x)) # Output between -1 and 1
        return x

def select_move(board, model):
    legal_moves = board.get_legal_moves()
    if not legal_moves:
        return None
    if random.random() < 0.1:  # Exploration: choose a random move sometimes
        return random.choice(legal_moves)
    else:  # Exploitation: choose the best move according to the model
        best_move = None
        best_score = -float('inf') if board.board.turn == chess.WHITE else float('inf')
        for move in legal_moves:
            temp_board = ChessBoard()
            temp_board = board.copy()  # Avoid modifying the original board
            temp_board.make_move(move)  # Make the move on the copied board
            state = temp_board.get_state()
            score = model(state.to(model.device)).item()
            if move.promotion:
                move.promotion = chess.QUEEN
            if (board.board.turn == chess.WHITE and score > best_score) or \
               (board.board.turn == chess.BLACK and score < best_score):
              best_score = score
              best_move = move
        return best_move

def train_model(model, num_episodes=1000, learning_rate=0.001):
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    for episode in range(num_episodes):
        board = ChessBoard()
        states, rewards = [], []
        while not board.is_game_over():
            state = board.get_state()
            move = select_move(board, model)
            if move is None: # No legal moves (should not happen with proper game state check)
              break
            board.make_move(move)
            states.append(state)

        result = board.get_result()
        if result is None: # Handle cases where game ends without a clear result (should not happen ideally)
          rewards = [0] * len(states)
        else:
          rewards = [result * (-1)**i for i in range(len(states))] #Assign reward based on win/loss/draw and turn

        # Update the model based on the game outcome
        for i in range(len(states)):
            state = states[i]
            reward = torch.tensor(rewards[i], dtype=torch.float32).to(model.device)
            score = model(state.to(model.device))
            loss = (score - reward)**2  # Mean Squared Error loss
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(f"Episode {episode + 1}/{num_episodes}, Result: {result}, Device: {model.device}")

def play_game(model1, model2):
    board = ChessBoard()
    while not board.is_game_over():
        if board.board.turn == chess.WHITE:
            move = select_move(board, model1)
        else:
            move = select_move(board, model2)
        if move is None: #Handle no legal moves (should not happen)
          break
        board.make_move(move)
        board.print_board()  # Print the board after each move
    result = board.get_result()
    if result == 1:
        print("White wins!")
    elif result == -1:
        print("Black wins!")
    else:
        print("Draw!")

def play_against_human(model):
    board = ChessBoard()
    while not board.is_game_over():
        board.print_board()
        if board.board.turn == chess.WHITE:
            while True:
                try:
                    human_move_str = input("Your move (white): ")
                    human_move = board.board.parse_uci(human_move_str)  # Parse UCI format
                    if human_move in board.get_legal_moves():
                        board.make_move(human_move)
                        break
                    else:
                        print("Illegal move. Try again.")
                except ValueError:
                    if "Choose promotion piece (Q, R, B, N):" in human_move_str:
                        promotion_piece = None
                        while promotion_piece not in [chess.QUEEN, chess.ROOK, chess.BISHOP, chess.KNIGHT]:
                            piece_str = input("Choose promotion piece (Q, R, B, N): ").upper()
                            if piece_str == 'Q': promotion_piece = chess.QUEEN
                            elif piece_str == 'R': promotion_piece = chess.ROOK
                            elif piece_str == 'B': promotion_piece = chess.BISHOP
                            elif piece_str == 'N': promotion_piece = chess.KNIGHT
                    print("Invalid move format. Use UCI notation (e.g., e2e4).")
        else:
            model_move = select_move(board, model)
            if model_move is None:
                break  # Should not happen, but handle it to prevent errors
            board.make_move(model_move)
            print(f"Model's move (black): {model_move.uci()}")

    board.print_board()  # Print final board
    result = board.get_result()
    if result == 1:
        print("White wins!")
    elif result == -1:
        print("Black wins!")
    else:
        print("Draw!")

def main():
  model = ChessNet()
  # Train the model (optional, can load a pre-trained model)
  # train_model(model, num_episodes=100)

  # To train against itself:
  # model2 = ChessNet()
  # train_model(model2, num_episodes=100) # Train another model to play against

  # Load a pretrained model (if available) - Replace with your path if needed
  # model.load_state_dict(torch.load("chess_model.pth", map_location=model.device))

  # Play a game against a random player (for testing):
  play_game(model, ChessNet())  # Using a new, untrained network as the opponent

  #Or play against itself:
  #play_game(model, model2)

  #Play a game against human
  #play_against_human(model)

if __name__ == "__main__":
    main()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_22464\3240067657.py:105: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\Scalar.cpp:23.)
#   score = model(state.to(model.device)).item()
#   r n b q k b n r
#   p p p p p p p p
#   . . . . . . . .
#   . . . . . . . .
#   . . . . . . . .
#   . . N . . . . .
#   P P P P P P P P
#   R . B Q K B N R
#   ----------------
#    a b c d e f g h
#   r n b q k b n r
#   p p p p p p . p
#   . . . . . . p .
#   . . . . . . . .
#   . . . . . . . .
#   . . N . . . . .
#   P P P P P P P P
#   R . B Q K B N R
#   ----------------
#    a b c d e f g h
#   r n b q k b n r
#   p p p p p p . p
#   . . . . . . p .
#   . . . . . . . .
#   . . . . P . . .
#   . . N . . . . .
#   P P P P . P P P
#   R . B Q K B N R
#   ----------------
#    a b c d e f g h
#   r n b q k . n r
#   p p p p p p b p
#   . . . . . . p .
# %%
import torch
import torch.nn as nn
import torch.optim as optim
import chess
import random


class ChessBoard:
    def __init__(self):
        self.board = chess.Board()

    def get_state(self):
        state = []
        for square in chess.SQUARES:
            piece = self.board.piece_at(square)
            if piece:
                value = piece.piece_type * (1 if piece.color else -1)
                state.append(value)
            else:
                state.append(0)
        return torch.tensor(state, dtype=torch.float32)

    def __str__(self):
        board_str = ""
        for row in range(8):
            board_str += str(8 - row) + " | "
            for col in range(8):
                square = chess.square(col, 7 - row)
                piece = self.board.piece_at(square)
                if piece:
                    if piece.color == chess.WHITE:
                        board_str += piece.symbol().upper() + "  "
                    else:
                        board_str += piece.symbol().lower() + "  "
                else:
                    board_str += ".  "
            board_str += "\n"
        board_str += "  | a  b  c  d  e  f  g  h"
        return board_str

    def print_board(self):
        print(self)

    def copy(self):
        new_board = ChessBoard()
        new_board.board = self.board.copy()
        return new_board

    def get_legal_moves(self):
        return list(self.board.legal_moves)

    def make_move(self, move):
        if move.promotion is not None:
            promotion_piece = None
            while promotion_piece not in [
                chess.QUEEN,
                chess.ROOK,
                chess.BISHOP,
                chess.KNIGHT,
            ]:
                piece_str = input("Choose promotion piece (Q, R, B, N): ").upper()
                if piece_str == "Q":
                    promotion_piece = chess.QUEEN
                elif piece_str == "R":
                    promotion_piece = chess.ROOK
                elif piece_str == "B":
                    promotion_piece = chess.BISHOP
                elif piece_str == "N":
                    promotion_piece = chess.KNIGHT
            move.promotion = promotion_piece
        self.board.push(move)

    def is_game_over(self):
        return self.board.is_game_over()

    def get_result(self):
        if self.board.is_checkmate():
            return 1 if self.board.turn == chess.BLACK else -1
        elif (
            self.board.is_stalemate()
            or self.board.is_insufficient_material()
            or self.board.is_seventyfive_moves()
            or self.board.is_fivefold_repetition()
            or self.board.is_variant_draw()
        ):
            return 0
        else:
            return None


class ChessNet(nn.Module):
    def __init__(self):
        super(ChessNet, self).__init__()
        self.fc1 = nn.Linear(64, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 1)

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.to(self.device)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.tanh(self.fc3(x))
        return x


def select_move(board, model):
    legal_moves = board.get_legal_moves()
    if not legal_moves:
        return None
    if random.random() < 0.1:
        return random.choice(legal_moves)
    else:
        best_move = None
        best_score = -float("inf") if board.board.turn == chess.WHITE else float("inf")
        for move in legal_moves:
            temp_board = board.copy()
            temp_board.make_move(move)
            state = temp_board.get_state()
            score = model(state.to(model.device)).item()
            if move.promotion:
                move.promotion = chess.QUEEN
            if (board.board.turn == chess.WHITE and score > best_score) or (
                board.board.turn == chess.BLACK and score < best_score
            ):
                best_score = score
                best_move = move
        return best_move


def train_model(model, num_episodes=1000, learning_rate=0.001):
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    for episode in range(num_episodes):
        board = ChessBoard()
        states, rewards = [], []
        while not board.is_game_over():
            state = board.get_state()
            move = select_move(board, model)
            if move is None:
                break
            board.make_move(move)
            states.append(state)

        result = board.get_result()
        if result is None:
            rewards = [0] * len(states)
        else:
            rewards = [result * (-1) ** i for i in range(len(states))]

        for i in range(len(states)):
            state = states[i]
            reward = torch.tensor(rewards[i], dtype=torch.float32).to(model.device)
            score = model(state.to(model.device))
            loss = (score - reward) ** 2
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(
            f"Episode {episode + 1}/{num_episodes}, Result: {result}, Device: {model.device}"
        )


def play_game(model1, model2):
    board = ChessBoard()
    while not board.is_game_over():
        if board.board.turn == chess.WHITE:
            move = select_move(board, model1)
        else:
            move = select_move(board, model2)
        if move is None:
            break
        board.make_move(move)
        board.print_board()
    result = board.get_result()
    if result == 1:
        print("White wins!")
    elif result == -1:
        print("Black wins!")
    else:
        print("Draw!")


def play_against_human(model):
    board = ChessBoard()
    while not board.is_game_over():
        board.print_board()
        if board.board.turn == chess.WHITE:
            while True:
                try:
                    human_move_str = input("Your move (white): ")
                    human_move = board.board.parse_uci(human_move_str)
                    if human_move in board.get_legal_moves():
                        board.make_move(human_move)
                        break
                    else:
                        print("Illegal move. Try again.")
                except ValueError:
                    print("Invalid move format. Use UCI notation (e.g., e2e4).")
        else:
            model_move = select_move(board, model)
            if model_move is None:
                break
            board.make_move(model_move)
            print(f"Model's move (black): {model_move.uci()}")

    board.print_board()
    result = board.get_result()
    if result == 1:
        print("White wins!")
    elif result == -1:
        print("Black wins!")
    else:
        print("Draw!")


def main():
    model = ChessNet()
    # train_model(model, num_episodes=100)

    play_game(model, ChessNet())

    # play_against_human(model)


if __name__ == "__main__":
    main()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16652\919510719.py:121: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\Scalar.cpp:23.)
#   score = model(state.to(model.device)).item()
# 8 | r  n  b  q  k  b  n  r
# 7 | p  p  p  p  p  p  p  p
# 6 | .  .  .  .  .  .  .  .
# 5 | .  .  .  .  .  .  .  .
# 4 | .  .  .  .  .  .  .  .
# 3 | .  .  .  .  .  .  .  N
# 2 | P  P  P  P  P  P  P  P
# 1 | R  N  B  Q  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | r  n  b  q  k  b  n  r
# 7 | p  p  p  .  p  p  p  p
# 6 | .  .  .  .  .  .  .  .
# 5 | .  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  .  .  .
# 3 | .  .  .  .  .  .  .  N
# 2 | P  P  P  P  P  P  P  P
# 1 | R  N  B  Q  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | r  n  b  q  k  b  n  r
# 7 | p  p  p  .  p  p  p  p
# 6 | .  .  .  .  .  .  .  .
# 5 | .  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  .  P  .
# 3 | .  .  .  .  .  .  .  N
# 2 | P  P  P  P  P  P  .  P
# 1 | R  N  B  Q  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | r  n  b  q  k  b  n  r
# 7 | p  p  p  .  p  p  p  .
# 6 | .  .  .  .  .  .  .  p
# 5 | .  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  .  P  .
# 3 | .  .  .  .  .  .  .  N
# 2 | P  P  P  P  P  P  .  P
# 1 | R  N  B  Q  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | r  n  b  q  k  b  n  r
# 7 | p  p  p  .  p  p  p  .
# 6 | .  .  .  .  .  .  .  p
# 5 | .  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  .  .  .  .  .  .  N
# 2 | P  P  P  P  P  .  .  P
# 1 | R  N  B  Q  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | r  n  b  q  k  b  n  .
# 7 | p  p  p  .  p  p  p  r
# 6 | .  .  .  .  .  .  .  p
# 5 | .  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  .  .  .  .  .  .  N
# 2 | P  P  P  P  P  .  .  P
# 1 | R  N  B  Q  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | r  n  b  q  k  b  n  .
# 7 | p  p  p  .  p  p  p  r
# 6 | .  .  .  .  .  .  .  p
# 5 | .  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  .  .  .  .  N
# 2 | P  .  P  P  P  .  .  P
# 1 | R  N  B  Q  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | r  n  b  .  k  b  n  .
# 7 | p  p  p  q  p  p  p  r
# 6 | .  .  .  .  .  .  .  p
# 5 | .  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  .  .  .  .  N
# 2 | P  .  P  P  P  .  .  P
# 1 | R  N  B  Q  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | r  n  b  .  k  b  n  .
# 7 | p  p  p  q  p  p  p  r
# 6 | .  .  .  .  .  .  .  p
# 5 | .  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  .  P  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  N  B  Q  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | r  n  b  .  k  b  n  .
# 7 | .  p  p  q  p  p  p  r
# 6 | .  .  .  .  .  .  .  p
# 5 | p  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  .  P  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  N  B  Q  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | r  n  b  .  k  b  n  .
# 7 | .  p  p  q  p  p  p  r
# 6 | .  .  .  .  .  .  .  p
# 5 | p  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  .  P  Q  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  N  B  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  b  .  k  b  n  .
# 7 | .  p  p  q  p  p  p  r
# 6 | r  .  .  .  .  .  .  p
# 5 | p  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  .  P  Q  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  N  B  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  b  .  k  b  n  .
# 7 | .  p  p  q  p  p  p  r
# 6 | r  .  .  .  .  .  .  p
# 5 | p  .  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  .  P  .  .  N
# 2 | P  .  P  P  .  .  Q  P
# 1 | R  N  B  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  b  .  k  b  n  .
# 7 | .  p  p  .  p  p  p  r
# 6 | r  .  .  .  .  .  .  p
# 5 | p  q  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  .  P  .  .  N
# 2 | P  .  P  P  .  .  Q  P
# 1 | R  N  B  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  b  .  k  b  n  .
# 7 | .  p  p  .  p  p  p  r
# 6 | r  .  .  .  .  .  .  p
# 5 | p  q  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  .  P  .  .  N
# 2 | P  .  P  P  Q  .  .  P
# 1 | R  N  B  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  b  n  .
# 7 | .  p  p  b  p  p  p  r
# 6 | r  .  .  .  .  .  .  p
# 5 | p  q  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  .  P  .  .  N
# 2 | P  .  P  P  Q  .  .  P
# 1 | R  N  B  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  b  n  .
# 7 | .  p  p  b  p  p  p  r
# 6 | r  .  .  .  .  .  .  p
# 5 | p  q  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  Q  P  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  N  B  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  b  n  .
# 7 | .  .  p  b  p  p  p  r
# 6 | r  p  .  .  .  .  .  p
# 5 | p  q  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  Q  P  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  N  B  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  b  n  .
# 7 | .  .  p  b  p  p  p  r
# 6 | r  p  .  .  .  .  .  p
# 5 | p  q  .  p  .  .  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  N  Q  P  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  .  B  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  b  n  .
# 7 | .  .  p  b  p  .  p  r
# 6 | r  p  .  .  .  .  .  p
# 5 | p  q  .  p  .  p  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  N  Q  P  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  .  B  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  b  n  .
# 7 | .  .  p  b  p  .  p  r
# 6 | r  p  .  .  .  .  .  p
# 5 | p  q  .  p  .  p  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  N  Q  P  .  .  N
# 2 | P  B  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  b  n  .
# 7 | .  .  .  b  p  .  p  r
# 6 | r  p  p  .  .  .  .  p
# 5 | p  q  .  p  .  p  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  N  Q  P  .  .  N
# 2 | P  B  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  b  n  .
# 7 | .  .  .  b  p  .  p  r
# 6 | r  p  p  .  .  .  .  p
# 5 | p  q  .  p  .  p  .  .
# 4 | N  .  .  .  .  P  P  .
# 3 | .  P  .  Q  P  .  .  N
# 2 | P  B  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  b  n  .
# 7 | .  .  .  b  .  .  p  r
# 6 | r  p  p  .  .  .  .  p
# 5 | p  q  .  p  p  p  .  .
# 4 | N  .  .  .  .  P  P  .
# 3 | .  P  .  Q  P  .  .  N
# 2 | P  B  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  b  n  .
# 7 | .  .  .  b  .  .  p  r
# 6 | r  N  p  .  .  .  .  p
# 5 | p  q  .  p  p  p  .  .
# 4 | .  .  .  .  .  P  P  .
# 3 | .  P  .  Q  P  .  .  N
# 2 | P  B  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  n  .
# 7 | .  .  .  b  .  .  p  r
# 6 | r  N  p  .  .  .  .  p
# 5 | p  q  .  p  p  p  .  .
# 4 | .  b  .  .  .  P  P  .
# 3 | .  P  .  Q  P  .  .  N
# 2 | P  B  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  n  .
# 7 | .  .  .  N  .  .  p  r
# 6 | r  .  p  .  .  .  .  p
# 5 | p  q  .  p  p  p  .  .
# 4 | .  b  .  .  .  P  P  .
# 3 | .  P  .  Q  P  .  .  N
# 2 | P  B  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  n  .
# 7 | .  .  .  N  .  .  p  r
# 6 | r  .  p  .  .  .  .  p
# 5 | p  q  .  .  p  p  .  .
# 4 | .  b  .  p  .  P  P  .
# 3 | .  P  .  Q  P  .  .  N
# 2 | P  B  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  n  .
# 7 | .  .  .  N  .  .  p  r
# 6 | r  .  p  .  .  .  .  p
# 5 | p  q  .  .  p  p  .  .
# 4 | .  b  .  B  .  P  P  .
# 3 | .  P  .  Q  P  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  n  .
# 7 | .  .  .  N  .  .  p  r
# 6 | r  .  p  .  .  .  .  p
# 5 | p  q  .  .  .  p  .  .
# 4 | .  b  .  p  .  P  P  .
# 3 | .  P  .  Q  P  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  n  .
# 7 | .  .  .  N  .  .  p  r
# 6 | r  .  p  .  .  .  .  p
# 5 | p  q  .  .  .  p  .  .
# 4 | .  b  .  P  .  P  P  .
# 3 | .  P  .  Q  .  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  n  .
# 7 | .  .  .  N  .  .  .  r
# 6 | r  .  p  .  .  .  p  p
# 5 | p  q  .  .  .  p  .  .
# 4 | .  b  .  P  .  P  P  .
# 3 | .  P  .  Q  .  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  n  .
# 7 | .  .  .  .  .  .  .  r
# 6 | r  .  p  .  .  N  p  p
# 5 | p  q  .  .  .  p  .  .
# 4 | .  b  .  P  .  P  P  .
# 3 | .  P  .  Q  .  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  .  .
# 7 | .  .  .  .  .  .  .  r
# 6 | r  .  p  .  .  n  p  p
# 5 | p  q  .  .  .  p  .  .
# 4 | .  b  .  P  .  P  P  .
# 3 | .  P  .  Q  .  .  .  N
# 2 | P  .  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  .  .
# 7 | .  .  .  .  .  .  .  r
# 6 | r  .  p  .  .  n  p  p
# 5 | p  q  .  .  .  p  .  .
# 4 | P  b  .  P  .  P  P  .
# 3 | .  P  .  Q  .  .  .  N
# 2 | .  .  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  .  .
# 7 | .  .  .  .  .  .  .  r
# 6 | r  .  p  .  .  .  p  p
# 5 | p  q  .  .  .  p  .  .
# 4 | P  b  .  P  n  P  P  .
# 3 | .  P  .  Q  .  .  .  N
# 2 | .  .  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  .  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  .  .
# 7 | .  .  .  .  .  .  .  r
# 6 | r  .  p  .  .  .  p  p
# 5 | p  q  .  .  .  p  .  .
# 4 | P  b  .  P  n  P  P  .
# 3 | .  P  .  Q  .  .  .  .
# 2 | .  .  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  N  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  .  .
# 7 | .  .  .  .  .  .  r  .
# 6 | r  .  p  .  .  .  p  p
# 5 | p  q  .  .  .  p  .  .
# 4 | P  b  .  P  n  P  P  .
# 3 | .  P  .  Q  .  .  .  .
# 2 | .  .  P  P  .  .  .  P
# 1 | R  .  .  .  K  B  N  R
#   | a  b  c  d  e  f  g  h
# 8 | .  n  .  .  k  .  .  .
# 7 | .  .  .  .  .  .
.  .  .  .  .  .  .
#   | a  b  c  d  e  f  g  h
# 8 | .  .  .  .  .  .  .  .
# 7 | .  .  .  .  P  k  .  .
# 6 | .  P  p  .  .  .  .  .
# 5 | .  .  .  .  .  P  .  p
# 4 | R  b  .  .  .  .  .  P
# 3 | .  P  .  P  .  .  K  .
# 2 | .  .  .  .  .  r  .  .
# 1 | .  .  .  .  .  .  .  .
#   | a  b  c  d  e  f  g  h
# 8 | .  .  .  .  .  .  .  .
# 7 | .  .  .  .  P  k  .  .
# 6 | .  P  p  .  .  .  .  .
# 5 | .  .  .  .  .  r  .  p
# 4 | R  b  .  .  .  .  .  P
# 3 | .  P  .  P  .  .  K  .
# 2 | .  .  .  .  .  .  .  .
# 1 | .  .  .  .  .  .  .  .
#   | a  b  c  d  e  f  g  h

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import chess
import random


class ChessBoard:
    def __init__(self):
        self.board = chess.Board()

    def get_state(self):
        state = []
        for square in chess.SQUARES:
            piece = self.board.piece_at(square)
            if piece:
                value = piece.piece_type * (1 if piece.color else -1)
                state.append(value)
            else:
                state.append(0)
        return torch.tensor(state, dtype=torch.float32)

    def __str__(self):
        board_str = ""
        for row in range(8):
            board_str += str(8 - row) + " | "
            for col in range(8):
                square = chess.square(col, 7 - row)
                piece = self.board.piece_at(square)
                if piece:
                    if piece.color == chess.WHITE:
                        board_str += piece.symbol().upper() + "  "
                    else:
                        board_str += piece.symbol().lower() + "  "
                else:
                    board_str += ".  "
            board_str += "\n"
        board_str += "  | a  b  c  d  e  f  g  h"
        return board_str

    def print_board(self):
        print(self)

    def copy(self):
        new_board = ChessBoard()
        new_board.board = self.board.copy()
        return new_board

    def get_legal_moves(self):
        return list(self.board.legal_moves)

    def make_move(self, move):
        self.board.push(move)

    def is_game_over(self):
        return self.board.is_game_over()

    def get_result(self):
        if self.board.is_checkmate():
            return 1 if self.board.turn == chess.BLACK else -1
        elif (
            self.board.is_stalemate()
            or self.board.is_insufficient_material()
            or self.board.is_seventyfive_moves()
            or self.board.is_fivefold_repetition()
            or self.board.is_variant_draw()
        ):
            return 0
        else:
            return None


class ChessNet(nn.Module):
    def __init__(self):
        super(ChessNet, self).__init__()
        self.fc1 = nn.Linear(64, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 1)

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.to(self.device)

    def forward(self, x):
        x = x.to(self.device)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.tanh(self.fc3(x))
        return x


def select_move(board, model):
    legal_moves = board.get_legal_moves()
    if not legal_moves:
        return None
    if random.random() < 0.1:
        return random.choice(legal_moves)
    else:
        best_move = None
        best_score = -float("inf") if board.board.turn == chess.WHITE else float("inf")
        for move in legal_moves:
            temp_board = board.copy()
            temp_board.make_move(move)
            state = temp_board.get_state().to(model.device)
            score = model(state).item()
            if move.promotion:
                move.promotion = chess.QUEEN
            if (board.board.turn == chess.WHITE and score > best_score) or (
                board.board.turn == chess.BLACK and score < best_score
            ):
                best_score = score
                best_move = move
        return best_move


def train_model(model, num_episodes=1000, learning_rate=0.001):
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    for episode in range(num_episodes):
        board = ChessBoard()
        states, rewards = [], []
        while not board.is_game_over():
            state = board.get_state().to(model.device)
            move = select_move(board, model)
            if move is None:
                break
            board.make_move(move)
            states.append(state)

        result = board.get_result()
        if result is None:
            rewards = [0] * len(states)
        else:
            rewards = [result * (-1) ** i for i in range(len(states))]

        for i in range(len(states)):
            state = states[i]
            reward = torch.tensor(rewards[i], dtype=torch.float32).to(model.device)
            score = model(state)
            loss = (score - reward) ** 2
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(
            f"Episode {episode + 1}/{num_episodes}, Result: {result}, Device: {model.device}"
        )


def play_game(model1, model2):
    board = ChessBoard()
    while not board.is_game_over():
        if board.board.turn == chess.WHITE:
            move = select_move(board, model1)
        else:
            move = select_move(board, model2)
        if move is None:
            break
        board.make_move(move)
        board.print_board()
    result = board.get_result()
    if result == 1:
        print("White wins!")
    elif result == -1:
        print("Black wins!")
    else:
        print("Draw!")


def play_against_human(model):
    board = ChessBoard()
    while not board.is_game_over():
        board.print_board()
        if board.board.turn == chess.WHITE:
            while True:
                try:
                    move_str = input("Your move (white): ")
                    move = board.board.parse_uci(move_str)
                    if move in board.get_legal_moves():
                        if move.promotion is not None:
                            while True:
                                piece_str = input(
                                    "Choose promotion piece (Q, R, B, N):"
                                ).upper()
                                if piece_str == "Q":
                                    move.promotion = chess.QUEEN
                                    break
                                elif piece_str == "R":
                                    move.promotion = chess.ROOK
                                    break
                                elif piece_str == "B":
                                    move.promotion = chess.BISHOP
                                    break
                                elif piece_str == "N":
                                    move.promotion = chess.KNIGHT
                                    break
                                else:
                                    print(
                                        "Invalid promotion piece. Choose Q, R, B, or N."
                                    )
                        board.make_move(move)
                        break  # Valid move, exit the loop
                    else:  # Not a legal move
                        print("Illegal move. Please try again.")
                except ValueError:
                    print("Invalid move format. Use UCI notation (e.g., e2e4).")
        else:
            model_move = select_move(board, model)
            if model_move is None:
                break
            board.make_move(model_move)
            print(f"Model's move (black): {model_move.uci()}")

    board.print_board()
    result = board.get_result()
    if result == 1:
        print("White wins!")
    elif result == -1:
        print("Black wins!")
    else:
        print("Draw!")


def main():
    model = ChessNet()
    train_model(model, num_episodes=100)

    # play_game(model, ChessNet())

    # play_against_human(model)


if __name__ == "__main__":
    main()
# Out:
# Episode 1/100, Result: 0, Device: cuda
# Episode 2/100, Result: 0, Device: cuda
# Episode 3/100, Result: 0, Device: cuda
# Episode 4/100, Result: 0, Device: cuda
# Episode 5/100, Result: 0, Device: cuda
# Episode 6/100, Result: 0, Device: cuda
# Episode 7/100, Result: 0, Device: cuda
# Episode 8/100, Result: 0, Device: cuda
# Episode 9/100, Result: 0, Device: cuda
# Episode 10/100, Result: 0, Device: cuda
# Episode 11/100, Result: 0, Device: cuda
# Episode 12/100, Result: 0, Device: cuda
# Episode 13/100, Result: 0, Device: cuda
# Episode 14/100, Result: 0, Device: cuda
# Episode 15/100, Result: 0, Device: cuda
# Episode 16/100, Result: 0, Device: cuda
# Episode 17/100, Result: 0, Device: cuda
# Episode 18/100, Result: -1, Device: cuda
# Episode 19/100, Result: 0, Device: cuda
# Episode 20/100, Result: 0, Device: cuda
# Episode 21/100, Result: 0, Device: cuda
# Episode 22/100, Result: 0, Device: cuda
# Episode 23/100, Result: 0, Device: cuda
# Episode 24/100, Result: 0, Device: cuda
# Episode 25/100, Result: 0, Device: cuda
# Episode 26/100, Result: 0, Device: cuda
# Episode 27/100, Result: 0, Device: cuda
# Episode 28/100, Result: 0, Device: cuda
# Episode 29/100, Result: 0, Device: cuda
# Episode 30/100, Result: 0, Device: cuda
# Episode 31/100, Result: 0, Device: cuda
# Episode 32/100, Result: 0, Device: cuda
# Episode 33/100, Result: 0, Device: cuda
# Episode 34/100, Result: 0, Device: cuda
# Episode 35/100, Result: 0, Device: cuda
# Episode 36/100, Result: 1, Device: cuda
# Episode 37/100, Result: 0, Device: cuda
# Episode 38/100, Result: 0, Device: cuda
# Episode 39/100, Result: 0, Device: cuda
# Episode 40/100, Result: 0, Device: cuda
# Episode 41/100, Result: 0, Device: cuda
# Episode 42/100, Result: 0, Device: cuda
# Episode 43/100, Result: 0, Device: cuda
# Episode 44/100, Result: 0, Device: cuda
# Episode 45/100, Result: 0, Device: cuda
# Episode 46/100, Result: 0, Device: cuda
# Episode 47/100, Result: 0, Device: cuda
# Episode 48/100, Result: 0, Device: cuda
# Episode 49/100, Result: 0, Device: cuda
# Episode 50/100, Result: 0, Device: cuda
# Episode 51/100, Result: 0, Device: cuda
# Episode 52/100, Result: -1, Device: cuda
# Episode 53/100, Result: 0, Device: cuda
# Episode 54/100, Result: 0, Device: cuda
# Episode 55/100, Result: 0, Device: cuda
# Episode 56/100, Result: 0, Device: cuda
# Episode 57/100, Result: 0, Device: cuda
# Episode 58/100, Result: 0, Device: cuda
# Episode 59/100, Result: 0, Device: cuda
# Episode 60/100, Result: 0, Device: cuda
# Episode 61/100, Result: 0, Device: cuda
# Episode 62/100, Result: 0, Device: cuda
# Episode 63/100, Result: 0, Device: cuda
# Episode 64/100, Result: 0, Device: cuda
# Episode 65/100, Result: 0, Device: cuda
# Episode 66/100, Result: 0, Device: cuda
# Episode 67/100, Result: 0, Device: cuda
# Episode 68/100, Result: 0, Device: cuda
# Episode 69/100, Result: 0, Device: cuda
# Episode 70/100, Result: 1, Device: cuda
# Episode 71/100, Result: 0, Device: cuda
# Episode 72/100, Result: 0, Device: cuda
# Episode 73/100, Result: 0, Device: cuda
# Episode 74/100, Result: 0, Device: cuda
# Episode 75/100, Result: 0, Device: cuda
# Episode 76/100, Result: 0, Device: cuda
# Episode 77/100, Result: 0, Device: cuda
# Episode 78/100, Result: 0, Device: cuda
# Episode 79/100, Result: 0, Device: cuda
# Episode 80/100, Result: 0, Device: cuda
# Episode 81/100, Result: 0, Device: cuda
# Episode 82/100, Result: 0, Device: cuda
# Episode 83/100, Result: 0, Device: cuda
# Episode 84/100, Result: 0, Device: cuda
# Episode 85/100, Result: 0, Device: cuda
# Episode 86/100, Result: 0, Device: cuda
# Episode 87/100, Result: 0, Device: cuda
# Episode 88/100, Result: 0, Device: cuda
# Episode 89/100, Result: 0, Device: cuda
# Episode 90/100, Result: 0, Device: cuda
# Episode 91/100, Result: 0, Device: cuda
# Episode 92/100, Result: 0, Device: cuda
# Episode 93/100, Result: 0, Device: cuda
# Episode 94/100, Result: 0, Device: cuda
# Episode 95/100, Result: 0, Device: cuda
# Episode 96/100, Result: 0, Device: cuda
# Episode 97/100, Result: 0, Device: cuda
# Episode 98/100, Result: 0, Device: cuda
# Episode 99/100, Result: 0, Device: cuda
# Episode 100/100, Result: -1, Device: cuda
