# %%
import pygame
import random
from enum import Enum
from collections import deque
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# ==== GAME SETUP ====
BLOCK_SIZE = 20
SPEED = 100  # reduce if too fast

class Direction(Enum):
    RIGHT = 1
    LEFT = 2
    UP = 3
    DOWN = 4

class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __eq__(self, other):
        if isinstance(other, Point):
            return self.x == other.x and self.y == other.y
        return False

class SnakeGameAI:
    def __init__(self, w=400, h=400):
        self.w = w
        self.h = h
        self.reset()
        self.display = pygame.display.set_mode((self.w, self.h))
        pygame.display.set_caption('Snake RL')
        self.clock = pygame.time.Clock()

    def reset(self):
        self.direction = Direction.RIGHT
        self.head = Point(self.w//2, self.h//2)
        self.snake = [self.head,
                      Point(self.head.x - BLOCK_SIZE, self.head.y),
                      Point(self.head.x - (2*BLOCK_SIZE), self.head.y)]
        self.score = 0
        self.food = None
        self._place_food()
        self.frame_iteration = 0

    def _place_food(self):
        x = random.randint(0, (self.w - BLOCK_SIZE) // BLOCK_SIZE) * BLOCK_SIZE
        y = random.randint(0, (self.h - BLOCK_SIZE) // BLOCK_SIZE) * BLOCK_SIZE
        self.food = Point(x, y)
        if self.food in self.snake:
            self._place_food()

    def play_step(self, action):
        self.frame_iteration += 1
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()

        self._move(action)  # Update the head
        self.snake.insert(0, self.head)

        reward = 0
        game_over = False
        if self._is_collision():
            game_over = True
            reward = -10
            return reward, game_over, self.score

        if self.head.x == self.food.x and self.head.y == self.food.y:
            self.score += 1
            reward = 10
            self._place_food()
        else:
            self.snake.pop()
        self._update_ui()
        self.clock.tick(SPEED)
        return reward, game_over, self.score

    def _is_collision(self, pt=None):
        if pt is None:
            pt = self.head
        return (
            pt.x >= self.w or pt.x < 0 or
            pt.y >= self.h or pt.y < 0 or
            pt in self.snake[1:]
        )

    def _update_ui(self):
        self.display.fill(pygame.Color('black'))
        for pt in self.snake:
            pygame.draw.rect(self.display, pygame.Color('green'), pygame.Rect(pt.x, pt.y, BLOCK_SIZE, BLOCK_SIZE))
        pygame.draw.rect(self.display, pygame.Color('red'), pygame.Rect(self.food.x, self.food.y, BLOCK_SIZE, BLOCK_SIZE))
        pygame.display.flip()

    def _move(self, action):
        clock_wise = [Direction.RIGHT, Direction.DOWN, Direction.LEFT, Direction.UP]
        idx = clock_wise.index(self.direction)

        if np.array_equal(action, [1, 0, 0]):
            new_dir = clock_wise[idx]  # straight
        elif np.array_equal(action, [0, 1, 0]):
            new_dir = clock_wise[(idx + 1) % 4]  # right turn
        else:
            new_dir = clock_wise[(idx - 1) % 4]  # left turn

        self.direction = new_dir

        x, y = self.snake[0].x, self.snake[0].y
        if self.direction == Direction.RIGHT:
            x += BLOCK_SIZE
        elif self.direction == Direction.LEFT:
            x -= BLOCK_SIZE
        elif self.direction == Direction.DOWN:
            y += BLOCK_SIZE
        elif self.direction == Direction.UP:
            y -= BLOCK_SIZE

        self.head = Point(x, y)  # set new head

    def get_state(self):
        head = self.snake[0]
        point_l = Point(head.x - BLOCK_SIZE, head.y)
        point_r = Point(head.x + BLOCK_SIZE, head.y)
        point_u = Point(head.x, head.y - BLOCK_SIZE)
        point_d = Point(head.x, head.y + BLOCK_SIZE)

        dir_l = self.direction == Direction.LEFT
        dir_r = self.direction == Direction.RIGHT
        dir_u = self.direction == Direction.UP
        dir_d = self.direction == Direction.DOWN

        # Danger detection (lookahead)
        danger_straight = (dir_r and self._is_collision(point_r)) or \
                          (dir_l and self._is_collision(point_l)) or \
                          (dir_u and self._is_collision(point_u)) or \
                          (dir_d and self._is_collision(point_d))

        danger_right = (dir_u and self._is_collision(point_r)) or \
                       (dir_d and self._is_collision(point_l)) or \
                       (dir_l and self._is_collision(point_u)) or \
                       (dir_r and self._is_collision(point_d))

        danger_left = (dir_u and self._is_collision(point_l)) or \
                      (dir_d and self._is_collision(point_r)) or \
                      (dir_l and self._is_collision(point_d)) or \
                      (dir_r and self._is_collision(point_u))

        # Food location
        food_left = self.food.x < head.x
        food_right = self.food.x > head.x
        food_up = self.food.y < head.y
        food_down = self.food.y > head.y

        state = [
            danger_straight,
            danger_right,
            danger_left,

            dir_l,
            dir_r,
            dir_u,
            dir_d,

            food_left,
            food_right,
            food_up,
            food_down
        ]

        return np.array(state, dtype=int)

# ==== AGENT + DQN ====
class Linear_QNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.l1 = nn.Linear(input_size, hidden_size)
        self.l2 = nn.Linear(hidden_size, hidden_size)
        self.l3 = nn.Linear(hidden_size, output_size)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.l1(x))
        x = self.relu(self.l2(x))
        x = self.l3(x)
        return x

class QTrainer:
    def __init__(self, model, target_model, lr, gamma):
        self.model = model
        self.target_model = target_model
        self.lr = lr
        self.gamma = gamma
        self.optimizer = optim.Adam(model.parameters(), lr=self.lr)
        self.criterion = nn.MSELoss()

    def train_step(self, state, action, reward, next_state, done):
        state = torch.tensor(state, dtype=torch.float)
        next_state = torch.tensor(next_state, dtype=torch.float)
        action = torch.tensor(action, dtype=torch.long)
        reward = torch.tensor(reward, dtype=torch.float)

        if len(state.shape) == 1:
            state = state.unsqueeze(0)
            next_state = next_state.unsqueeze(0)
            action = action.unsqueeze(0)
            reward = reward.unsqueeze(0)
            done = (done, )

        pred = self.model(state)
        target = pred.clone()
        for idx in range(len(done)):
            Q_new = reward[idx]
            if not done[idx]:
                with torch.no_grad():
                    # 1. Select best action using current model
                    next_q_values = self.model(next_state[idx])
                    next_action = torch.argmax(next_q_values).item()

                    # 2. Evaluate that action using target model
                    target_q_values = self.target_model(next_state[idx])
                    max_next_q = target_q_values[next_action]

                    # 3. Compute target
                    Q_new = reward[idx] + self.gamma * max_next_q
            target[idx][torch.argmax(action[idx]).item()] = Q_new

        self.optimizer.zero_grad()
        loss = self.criterion(target, pred)
        loss.backward()
        self.optimizer.step()

class Agent:
    def __init__(self):
        self.n_games = 0
        self.epsilon = 0  # randomness
        self.gamma = 0.9  # discount rate
        self.memory = deque(maxlen=100000)  # Replay buffer size
        self.model = Linear_QNet(11, 256, 3)  # Main Q-network model
        self.target_model = Linear_QNet(11, 256, 3) 
        self.target_model.load_state_dict(self.model.state_dict())
        self.target_model.eval()
        self.trainer = QTrainer(self.model, self.target_model, lr=0.001, gamma=self.gamma)
        self.update_target_network_counter = 0
        self.target_update_interval = 5  # Update target model every 1000 steps
        self.steps_counter = 0
        self.min_epsilon = 20
        self.max_epsilon = 80
        self.epsilon_decay = 0.5
        # self.update_target_model()
        
    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        # Count steps for target network update
        self.steps_counter += 1
        if self.steps_counter >= self.target_update_interval:
            self.update_target_model()
            self.steps_counter = 0

    def train_long_memory(self):
        if len(self.memory) > 1000:
            mini_sample = random.sample(self.memory, 1000)  # Sample from memory
        else:
            mini_sample = self.memory

        # if self.n_games % 5 == 0:  # update target model every 5 games
        #     self.update_target_model()

        states, actions, rewards, next_states, dones = zip(*mini_sample)
        self.trainer.train_step(states, actions, rewards, next_states, dones)

    def train_short_memory(self, state, action, reward, next_state, done):
        self.trainer.train_step(state, action, reward, next_state, done)

    # def update_target_network(self):
    #     self.update_target_network_counter += 1
    #     if self.update_target_network_counter >= self.target_update_interval:
    #         self.update_target_network()

    def get_action(self, state):
        self.epsilon = self.max_epsilon - self.n_games * self.epsilon_decay  # Reduce exploration over time
        self.epsilon = max(self.min_epsilon, self.epsilon)
            
        final_move = [0, 0, 0]
        if random.randint(0, 100) < self.epsilon:
            move = random.randint(0, 2)
            final_move[move] = 1
        else:
            state0 = torch.tensor(state, dtype=torch.float)
            prediction = self.model(state0)
            move = torch.argmax(prediction).item()
            final_move[move] = 1
        return final_move

# ==== MAIN LOOP ====
def train():
    pygame.init()
    game = SnakeGameAI()
    agent = Agent()
    record = 0

    while True:
        state_old = game.get_state()
        final_move = agent.get_action(state_old)
        reward, done, score = game.play_step(final_move)
        state_new = game.get_state()

        agent.train_short_memory(state_old, final_move, reward, state_new, done)
        agent.remember(state_old, final_move, reward, state_new, done)

        if done:
            game.reset()
            agent.n_games += 1
            agent.train_long_memory()

            # # Update target network every N games
            # if agent.n_games % agent.target_update_interval == 0:
            #     agent.update_target_network()

            if score > record:
                record = score
                torch.save(agent.model.state_dict(), 'model.pth')

            print(f'Game: {agent.n_games}, Score: {score}, Record: {record}')


if __name__ == '__main__':
    train()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_28916\2121182124.py:202: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:257.)
#   state = torch.tensor(state, dtype=torch.float)
# Game: 1, Score: 0, Record: 0
# Game: 2, Score: 0, Record: 0
# Game: 3, Score: 0, Record: 0
# Game: 4, Score: 0, Record: 0
# Game: 5, Score: 0, Record: 0
# Game: 6, Score: 1, Record: 1
# Game: 7, Score: 0, Record: 1
# Game: 8, Score: 0, Record: 1
# Game: 9, Score: 0, Record: 1
# Game: 10, Score: 0, Record: 1
# Game: 11, Score: 0, Record: 1
# Game: 12, Score: 1, Record: 1
# Game: 13, Score: 0, Record: 1
# Game: 14, Score: 0, Record: 1
# Game: 15, Score: 0, Record: 1
# Game: 16, Score: 0, Record: 1
# Game: 17, Score: 0, Record: 1
# Game: 18, Score: 0, Record: 1
# Game: 19, Score: 0, Record: 1
# Game: 20, Score: 1, Record: 1
# Game: 21, Score: 0, Record: 1
# Game: 22, Score: 0, Record: 1
# Game: 23, Score: 0, Record: 1
# Game: 24, Score: 0, Record: 1
# Game: 25, Score: 0, Record: 1
# Game: 26, Score: 0, Record: 1
# Game: 27, Score: 1, Record: 1
# Game: 28, Score: 0, Record: 1
# Game: 29, Score: 0, Record: 1
# Game: 30, Score: 1, Record: 1
# Game: 31, Score: 0, Record: 1
# Game: 32, Score: 1, Record: 1
# Game: 33, Score: 0, Record: 1
# Game: 34, Score: 0, Record: 1
# Game: 35, Score: 1, Record: 1
# Game: 36, Score: 0, Record: 1
# Game: 37, Score: 0, Record: 1
# Game: 38, Score: 0, Record: 1
# Game: 39, Score: 1, Record: 1
# Game: 40, Score: 1, Record: 1
# Game: 41, Score: 0, Record: 1
# Game: 42, Score: 1, Record: 1
# Game: 43, Score: 0, Record: 1
# Game: 44, Score: 0, Record: 1
# Game: 45, Score: 0, Record: 1
# Game: 46, Score: 0, Record: 1
# Game: 47, Score: 0, Record: 1
# Game: 48, Score: 1, Record: 1
# Game: 49, Score: 0, Record: 1
# Game: 50, Score: 0, Record: 1
# Game: 51, Score: 0, Record: 1
# Game: 52, Score: 1, Record: 1
# Game: 53, Score: 0, Record: 1
# Game: 54, Score: 0, Record: 1
# Game: 55, Score: 3, Record: 3
# Game: 56, Score: 0, Record: 3
# Game: 57, Score: 0, Record: 3
# Game: 58, Score: 0, Record: 3
# Game: 59, Score: 1, Record: 3
# Game: 60, Score: 0, Record: 3
# Game: 61, Score: 2, Record: 3
# Game: 62, Score: 1, Record: 3
# Game: 63, Score: 1, Record: 3
# Game: 64, Score: 1, Record: 3
# Game: 65, Score: 1, Record: 3
# Game: 66, Score: 0, Record: 3
# Game: 67, Score: 1, Record: 3
# Game: 68, Score: 0, Record: 3
# Game: 69, Score: 1, Record: 3
# Game: 70, Score: 0, Record: 3
# Game: 71, Score: 1, Record: 3
# Game: 72, Score: 1, Record: 3
# Game: 73, Score: 0, Record: 3
# Game: 74, Score: 0, Record: 3
# Game: 75, Score: 2, Record: 3
# Game: 76, Score: 2, Record: 3
# Game: 77, Score: 0, Record: 3
# Game: 78, Score: 1, Record: 3
# Game: 79, Score: 1, Record: 3
# Game: 80, Score: 0, Record: 3
# Game: 81, Score: 1, Record: 3
# Game: 82, Score: 1, Record: 3
# Game: 83, Score: 1, Record: 3
# Game: 84, Score: 1, Record: 3
# Game: 85, Score: 1, Record: 3
# Game: 86, Score: 0, Record: 3
# Game: 87, Score: 0, Record: 3
# Game: 88, Score: 0, Record: 3
# Game: 89, Score: 1, Record: 3
# Game: 90, Score: 1, Record: 3
# Game: 91, Score: 0, Record: 3
# Game: 92, Score: 0, Record: 3
# Game: 93, Score: 1, Record: 3
# Game: 94, Score: 3, Record: 3
# Game: 95, Score: 2, Record: 3
# Game: 96, Score: 2, Record: 3
# Game: 97, Score: 1, Record: 3
# Game: 98, Score: 1, Record: 3
# Game: 99, Score: 2, Record: 3
# Game: 100, Score: 0, Record: 3
# Game: 101, Score: 1, Record: 3
# Game: 102, Score: 1, Record: 3
# Game: 103, Score: 1, Record: 3
# Game: 104, Score: 1, Record: 3
# Game: 105, Score: 2, Record: 3
# Game: 106, Score: 1, Record: 3
# Game: 107, Score: 1, Record: 3
# Game: 108, Score: 0, Record: 3
# Game: 109, Score: 4, Record: 4
# Game: 110, Score: 0, Record: 4
# Game: 111, Score: 0, Record: 4
# Game: 112, Score: 1, Record: 4
# Game: 113, Score: 0, Record: 4
# Game: 114, Score: 0, Record: 4
# Game: 115, Score: 1, Record: 4
# Game: 116, Score: 2, Record: 4
# Game: 117, Score: 0, Record: 4
# Game: 118, Score: 1, Record: 4
# Game: 119, Score: 1, Record: 4
# Game: 120, Score: 2, Record: 4
# Game: 121, Score: 1, Record: 4
# Game: 122, Score: 1, Record: 4
# Game: 123, Score: 5, Record: 5
# Game: 124, Score: 1, Record: 5
# Game: 125, Score: 6, Record: 6
# Game: 126, Score: 5, Record: 6
# Game: 127, Score: 6, Record: 6
# Game: 128, Score: 1, Record: 6
# Game: 129, Score: 4, Record: 6
# Game: 130, Score: 1, Record: 6
# Game: 131, Score: 3, Record: 6
# Game: 132, Score: 4, Record: 6
# Game: 133, Score: 2, Record: 6
# Game: 134, Score: 3, Record: 6
# Game: 135, Score: 5, Record: 6
# Game: 136, Score: 5, Record: 6
# Game: 137, Score: 5, Record: 6
# Game: 138, Score: 6, Record: 6
# Game: 139, Score: 2, Record: 6
# Game: 140, Score: 8, Record: 8
# Game: 141, Score: 12, Record: 12
# Game: 142, Score: 8, Record: 12
# Game: 143, Score: 0, Record: 12
# Game: 144, Score: 2, Record: 12
# Game: 145, Score: 1, Record: 12
# Game: 146, Score: 3, Record: 12
# Game: 147, Score: 5, Record: 12
# Game: 148, Score: 7, Record: 12
# Game: 149, Score: 6, Record: 12
# Game: 150, Score: 5, Record: 12
# Game: 151, Score: 3, Record: 12
# Game: 152, Score: 0, Record: 12
# Game: 153, Score: 1, Record: 12
# Game: 154, Score: 5, Record: 12
# Game: 155, Score: 10, Record: 12
# Game: 156, Score: 4, Record: 12
# Game: 157, Score: 2, Record: 12
# Game: 158, Score: 1, Record: 12
# Game: 159, Score: 0, Record: 12
# Game: 160, Score: 3, Record: 12
# Game: 161, Score: 1, Record: 12
# Game: 162, Score: 4, Record: 12
# Game: 163, Score: 1, Record: 12
# Game: 164, Score: 1, Record: 12
# Game: 165, Score: 1, Record: 12
# Game: 166, Score: 2, Record: 12
# Game: 167, Score: 7, Record: 12
# Game: 168, Score: 2, Record: 12
# Game: 169, Score: 1, Record: 12
# Game: 170, Score: 5, Record: 12
# Game: 171, Score: 4, Record: 12
# Game: 172, Score: 5, Record: 12
# Game: 173, Score: 2, Record: 12
# Game: 174, Score: 1, Record: 12
# Game: 175, Score: 0, Record: 12
# Game: 176, Score: 3, Record: 12
# Game: 177, Score: 10, Record: 12
# Game: 178, Score: 2, Record: 12
# Game: 179, Score: 6, Record: 12
# Game: 180, Score: 1, Record: 12
# Game: 181, Score: 5, Record: 12
# Game: 182, Score: 2, Record: 12
# Game: 183, Score: 3, Record: 12
# Game: 184, Score: 6, Record: 12
# Game: 185, Score: 2, Record: 12
# Game: 186, Score: 7, Record: 12
# Game: 187, Score: 5, Record: 12
# Game: 188, Score: 2, Record: 12
# Game: 189, Score: 2, Record: 12
# Game: 190, Score: 2, Record: 12
# Game: 191, Score: 2, Record: 12
# Game: 192, Score: 2, Record: 12
# Game: 193, Score: 5, Record: 12
# Game: 194, Score: 1, Record: 12
# Game: 195, Score: 5, Record: 12
# Game: 196, Score: 11, Record: 12
# Game: 197, Score: 2, Record: 12
# Game: 198, Score: 7, Record: 12
# Game: 199, Score: 1, Record: 12
# Game: 200, Score: 1, Record: 12
# Game: 201, Score: 4, Record: 12
# Game: 202, Score: 11, Record: 12
# Game: 203, Score: 4, Record: 12
# Game: 204, Score: 2, Record: 12
# Game: 205, Score: 3, Record: 12
# Game: 206, Score: 6, Record: 12
# Game: 207, Score: 1, Record: 12
# Game: 208, Score: 6, Record: 12
# Game: 209, Score: 3, Record: 12
# Game: 210, Score: 1, Record: 12
# Game: 211, Score: 1, Record: 12
# Game: 212, Score: 4, Record: 12
# Game: 213, Score: 6, Record: 12
# Game: 214, Score: 1, Record: 12
# Game: 215, Score: 1, Record: 12
# Game: 216, Score: 5, Record: 12
# Game: 217, Score: 1, Record: 12
# Game: 218, Score: 5, Record: 12
# Game: 219, Score: 7, Record: 12
# Game: 220, Score: 6, Record: 12
# Game: 221, Score: 1, Record: 12
# Game: 222, Score: 1, Record: 12
# Game: 223, Score: 2, Record: 12
# Game: 224, Score: 1, Record: 12
# Game: 225, Score: 3, Record: 12
# Game: 226, Score: 3, Record: 12
# Game: 227, Score: 7, Record: 12
# Game: 228, Score: 2, Record: 12
# Game: 229, Score: 1, Record: 12
# Game: 230, Score: 4, Record: 12
# Game: 231, Score: 6, Record: 12
# Game: 232, Score: 7, Record: 12
# Game: 233, Score: 5, Record: 12
# Game: 234, Score: 5, Record: 12
# Game: 235, Score: 13, Record: 13
# Game: 236, Score: 8, Record: 13
# Game: 237, Score: 1, Record: 13
# Game: 238, Score: 1, Record: 13
# Game: 239, Score: 2, Record: 13
# Game: 240, Score: 15, Record: 15
# Game: 241, Score: 3, Record: 15
# Game: 242, Score: 1, Record: 15
# Game: 243, Score: 5, Record: 15
# Game: 244, Score: 8, Record: 15
# Game: 245, Score: 10, Record: 15
# Game: 246, Score: 3, Record: 15
# Game: 247, Score: 10, Record: 15
# Game: 248, Score: 1, Record: 15
# Game: 249, Score: 5, Record: 15
# Game: 250, Score: 2, Record: 15
# Game: 251, Score: 6, Record: 15
# Game: 252, Score: 3, Record: 15
# Game: 253, Score: 3, Record: 15
# Game: 254, Score: 11, Record: 15
# Game: 255, Score: 5, Record: 15
# Game: 256, Score: 2, Record: 15
# Game: 257, Score: 1, Record: 15
# Game: 258, Score: 5, Record: 15
# Game: 259, Score: 1, Record: 15
# Game: 260, Score: 5, Record: 15
# Game: 261, Score: 4, Record: 15
# Game: 262, Score: 1, Record: 15
# Game: 263, Score: 2, Record: 15
# Game: 264, Score: 9, Record: 15
# Game: 265, Score: 1, Record: 15
# Game: 266, Score: 3, Record: 15
# Game: 267, Score: 5, Record: 15
# Game: 268, Score: 4, Record: 15
# Game: 269, Score: 4, Record: 15
# Game: 270, Score: 4, Record: 15
# Game: 271, Score: 1, Record: 15
# Game: 272, Score: 12, Record: 15
# Game: 273, Score: 2, Record: 15
# Game: 274, Score: 7, Record: 15
# Game: 275, Score: 14, Record: 15
# Game: 276, Score: 5, Record: 15
# Game: 277, Score: 5, Record: 15
# Game: 278, Score: 0, Record: 15
# Game: 279, Score: 6, Record: 15
# Game: 280, Score: 15, Record: 15
# Game: 281, Score: 1, Record: 15
# Game: 282, Score: 5, Record: 15
# Game: 283, Score: 3, Record: 15
# Game: 284, Score: 4, Record: 15
# Game: 285, Score: 2, Record: 15
# Game: 286, Score: 1, Record: 15
# Game: 287, Score: 3, Record: 15
# Game: 288, Score: 4, Record: 15
# Game: 289, Score: 8, Record: 15
# Game: 290, Score: 2, Record: 15
# Game: 291, Score: 1, Record: 15
# Game: 292, Score: 2, Record: 15
# Game: 293, Score: 3, Record: 15
# Game: 294, Score: 2, Record: 15
# Game: 295, Score: 1, Record: 15
# Game: 296, Score: 1, Record: 15
# Game: 297, Score: 8, Record: 15
# Game: 298, Score: 3, Record: 15
# Game: 299, Score: 5, Record: 15
# Game: 300, Score: 3, Record: 15
# Game: 301, Score: 5, Record: 15
# Game: 302, Score: 7, Record: 15
# Game: 303, Score: 11, Record: 15
# Game: 304, Score: 6, Record: 15
# Game: 305, Score: 3, Record: 15
# Game: 306, Score: 5, Record: 15
# Game: 307, Score: 12, Record: 15
# Game: 308, Score: 1, Record: 15
# Game: 309, Score: 3, Record: 15
# Game: 310, Score: 6, Record: 15
# Game: 311, Score: 8, Record: 15
# Game: 312, Score: 8, Record: 15
# Game: 313, Score: 1, Record: 15
# Game: 314, Score: 2, Record: 15
# Game: 315, Score: 3, Record: 15
# Game: 316, Score: 3, Record: 15
# Game: 317, Score: 2, Record: 15
# Game: 318, Score: 1, Record: 15
# Game: 319, Score: 5, Record: 15
# Game: 320, Score: 2, Record: 15
# Game: 321, Score: 1, Record: 15
# Game: 322, Score: 5, Record: 15
# Game: 323, Score: 5, Record: 15
# Game: 324, Score: 0, Record: 15
# Game: 325, Score: 3, Record: 15
# Game: 326, Score: 5, Record: 15
# Game: 327, Score: 5, Record: 15
# Game: 328, Score: 2, Record: 15
# Game: 329, Score: 14, Record: 15
# Game: 330, Score: 12, Record: 15
# Game: 331, Score: 4, Record: 15
# Game: 332, Score: 2, Record: 15
# Game: 333, Score: 4, Record: 15
# Game: 334, Score: 3, Record: 15
# Game: 335, Score: 1, Record: 15
# Game: 336, Score: 10, Record: 15
# Game: 337, Score: 4, Record: 15
# Game: 338, Score: 1, Record: 15
# Game: 339, Score: 11, Record: 15
# Game: 340, Score: 8, Record: 15
# Game: 341, Score: 7, Record: 15
# Game: 342, Score: 2, Record: 15
# Game: 343, Score: 5, Record: 15
# Game: 344, Score: 1, Record: 15
# Game: 345, Score: 1, Record: 15
# Game: 346, Score: 9, Record: 15
# Game: 347, Score: 7, Record: 15
# Game: 348, Score: 9, Record: 15
# Game: 349, Score: 1, Record: 15
# Game: 350, Score: 7, Record: 15
# Game: 351, Score: 1, Record: 15
# Game: 352, Score: 6, Record: 15
# Game: 353, Score: 9, Record: 15
# Game: 354, Score: 1, Record: 15
# Game: 355, Score: 2, Record: 15
# Game: 356, Score: 4, Record: 15
# Game: 357, Score: 4, Record: 15
# Game: 358, Score: 3, Record: 15
# Game: 359, Score: 2, Record: 15
# Game: 360, Score: 8, Record: 15
# Game: 361, Score: 13, Record: 15
# Game: 362, Score: 9, Record: 15
# Game: 363, Score: 4, Record: 15
# Game: 364, Score: 3, Record: 15
# Game: 365, Score: 4, Record: 15
# Game: 366, Score: 5, Record: 15
# Game: 367, Score: 3, Record: 15
# Game: 368, Score: 5, Record: 15
# Game: 369, Score: 3, Record: 15
# Game: 370, Score: 1, Record: 15
# Game: 371, Score: 3, Record: 15
# Game: 372, Score: 1, Record: 15
# Game: 373, Score: 0, Record: 15
# Game: 374, Score: 10, Record: 15
# Game: 375, Score: 8, Record: 15
# Game: 376, Score: 2, Record: 15
# Game: 377, Score: 1, Record: 15
# Game: 378, Score: 9, Record: 15
# Game: 379, Score: 8, Record: 15
# Game: 380, Score: 6, Record: 15
# Game: 381, Score: 5, Record: 15
# Game: 382, Score: 3, Record: 15
# Game: 383, Score: 5, Record: 15
# Game: 384, Score: 3, Record: 15
# Game: 385, Score: 4, Record: 15
# Game: 386, Score: 10, Record: 15
# Game: 387, Score: 2, Record: 15
# Game: 388, Score: 0, Record: 15
# Game: 389, Score: 6, Record: 15
# Game: 390, Score: 2, Record: 15
# Game: 391, Score: 3, Record: 15
# Game: 392, Score: 4, Record: 15
# Game: 393, Score: 0, Record: 15
# Game: 394, Score: 2, Record: 15
# Game: 395, Score: 6, Record: 15
# Game: 396, Score: 3, Record: 15
# Game: 397, Score: 6, Record: 15
# Game: 398, Score: 2, Record: 15
# Game: 399, Score: 6, Record: 15
# Game: 400, Score: 7, Record: 15
# Game: 401, Score: 8, Record: 15
# Game: 402, Score: 2, Record: 15
# Game: 403, Score: 0, Record: 15
# Game: 404, Score: 4, Record: 15
# Game: 405, Score: 5, Record: 15
# Game: 406, Score: 7, Record: 15
# Game: 407, Score: 0, Record: 15
# Game: 408, Score: 3, Record: 15
# Game: 409, Score: 7, Record: 15
# Game: 410, Score: 8, Record: 15
# Game: 411, Score: 7, Record: 15
# Game: 412, Score: 1, Record: 15
# Game: 413, Score: 1, Record: 15
# Game: 414, Score: 3, Record: 15
# Game: 415, Score: 5, Record: 15
# Game: 416, Score: 0, Record: 15
# Game: 417, Score: 1, Record: 15
# Game: 418, Score: 4, Record: 15
# Game: 419, Score: 6, Record: 15
# Game: 420, Score: 5, Record: 15
# Game: 421, Score: 9, Record: 15
# Game: 422, Score: 6, Record: 15
# Game: 423, Score: 10, Record: 15
# Game: 424, Score: 3, Record: 15
# Game: 425, Score: 2, Record: 15
# Game: 426, Score: 1, Record: 15
# Game: 427, Score: 2, Record: 15
# Game: 428, Score: 1, Record: 15
# Game: 429, Score: 7, Record: 15
# Game: 430, Score: 1, Record: 15
# Game: 431, Score: 1, Record: 15
# Game: 432, Score: 6, Record: 15
# Game: 433, Score: 9, Record: 15
# Game: 434, Score: 8, Record: 15
# Game: 435, Score: 2, Record: 15
# Game: 436, Score: 4, Record: 15
# Game: 437, Score: 6, Record: 15
# Game: 438, Score: 8, Record: 15
# Game: 439, Score: 1, Record: 15
# Game: 440, Score: 6, Record: 15
# Game: 441, Score: 4, Record: 15
# Game: 442, Score: 10, Record: 15
# Game: 443, Score: 1, Record: 15
# Game: 444, Score: 4, Record: 15
# Game: 445, Score: 2, Record: 15
# Game: 446, Score: 1, Record: 15
# Game: 447, Score: 4, Record: 15
# Game: 448, Score: 1, Record: 15
# Game: 449, Score: 2, Record: 15
# Game: 450, Score: 1, Record: 15
# Game: 451, Score: 8, Record: 15
# Game: 452, Score: 7, Record: 15
# Game: 453, Score: 1, Record: 15
# Game: 454, Score: 7, Record: 15
# Game: 455, Score: 2, Record: 15
# Game: 456, Score: 3, Record: 15
# Game: 457, Score: 4, Record: 15
# Game: 458, Score: 2, Record: 15
# Game: 459, Score: 7, Record: 15
# Game: 460, Score: 8, Record: 15
# Game: 461, Score: 18, Record: 18
# Game: 462, Score: 11, Record: 18
# Game: 463, Score: 4, Record: 18
# Game: 464, Score: 2, Record: 18
# Game: 465, Score: 10, Record: 18
# Game: 466, Score: 8, Record: 18
# Game: 467, Score: 2, Record: 18
# Game: 468, Score: 4, Record: 18
# Game: 469, Score: 1, Record: 18
# Game: 470, Score: 8, Record: 18
# Game: 471, Score: 4, Record: 18
# Game: 472, Score: 5, Record: 18
# Game: 473, Score: 1, Record: 18
# Game: 474, Score: 0, Record: 18
# Game: 475, Score: 12, Record: 18
# Game: 476, Score: 8, Record: 18
# Game: 477, Score: 4, Record: 18
# Game: 478, Score: 1, Record: 18
# Game: 479, Score: 9, Record: 18
# Game: 480, Score: 3, Record: 18
# Game: 481, Score: 3, Record: 18
# Game: 482, Score: 7, Record: 18
# Game: 483, Score: 4, Record: 18
# Game: 484, Score: 2, Record: 18
# Game: 485, Score: 1, Record: 18
# Game: 486, Score: 10, Record: 18
# Game: 487, Score: 2, Record: 18
# Game: 488, Score: 6, Record: 18
# Game: 489, Score: 6, Record: 18
# Game: 490, Score: 8, Record: 18
# Game: 491, Score: 2, Record: 18
# Game: 492, Score: 2, Record: 18
# Game: 493, Score: 3, Record: 18
# Game: 494, Score: 11, Record: 18
# Game: 495, Score: 1, Record: 18
# Game: 496, Score: 5, Record: 18
# Game: 497, Score: 4, Record: 18
# Game: 498, Score: 5, Record: 18
# Game: 499, Score: 1, Record: 18
# Game: 500, Score: 6, Record: 18
# Game: 501, Score: 1, Record: 18
# Game: 502, Score: 1, Record: 18
# Game: 503, Score: 2, Record: 18
# Game: 504, Score: 3, Record: 18
# Game: 505, Score: 1, Record: 18
# Game: 506, Score: 1, Record: 18
# Game: 507, Score: 3, Record: 18
# Game: 508, Score: 6, Record: 18
# Game: 509, Score: 1, Record: 18
# Game: 510, Score: 3, Record: 18
# Game: 511, Score: 6, Record: 18
# Game: 512, Score: 4, Record: 18
# Game: 513, Score: 8, Record: 18
# Game: 514, Score: 12, Record: 18
# Game: 515, Score: 3, Record: 18
# Game: 516, Score: 3, Record: 18
# Game: 517, Score: 2, Record: 18
# Game: 518, Score: 15, Record: 18
# Game: 519, Score: 3, Record: 18
# Game: 520, Score: 21, Record: 21
# Game: 521, Score: 3, Record: 21
# Game: 522, Score: 9, Record: 21
# Game: 523, Score: 3, Record: 21
# Game: 524, Score: 2, Record: 21
# Game: 525, Score: 7, Record: 21
# Game: 526, Score: 1, Record: 21
# Game: 527, Score: 2, Record: 21
# Game: 528, Score: 9, Record: 21
# Game: 529, Score: 4, Record: 21
# Game: 530, Score: 1, Record: 21
# Game: 531, Score: 12, Record: 21
# Game: 532, Score: 2, Record: 21
# Game: 533, Score: 4, Record: 21
# Game: 534, Score: 9, Record: 21
# Game: 535, Score: 1, Record: 21
# Game: 536, Score: 3, Record: 21
# Game: 537, Score: 1, Record: 21
# Game: 538, Score: 2, Record: 21
# Game: 539, Score: 1, Record: 21
# Game: 540, Score: 0, Record: 21
# Game: 541, Score: 1, Record: 21
# Game: 542, Score: 9, Record: 21
# Game: 543, Score: 3, Record: 21
# Game: 544, Score: 1, Record: 21
# Game: 545, Score: 4, Record: 21
# Game: 546, Score: 11, Record: 21
# Game: 547, Score: 3, Record: 21
# Game: 548, Score: 7, Record: 21
# Game: 549, Score: 6, Record: 21
# Game: 550, Score: 3, Record: 21
# Game: 551, Score: 1, Record: 21
# Game: 552, Score: 2, Record: 21
# Game: 553, Score: 3, Record: 21
# Game: 554, Score: 2, Record: 21
# Game: 555, Score: 5, Record: 21
# Game: 556, Score: 1, Record: 21
# Game: 557, Score: 5, Record: 21
# Game: 558, Score: 1, Record: 21
# Game: 559, Score: 1, Record: 21
# Game: 560, Score: 9, Record: 21
# Game: 561, Score: 3, Record: 21
# Game: 562, Score: 4, Record: 21
# Game: 563, Score: 3, Record: 21
# Game: 564, Score: 2, Record: 21
# Game: 565, Score: 1, Record: 21
# Game: 566, Score: 2, Record: 21
# Game: 567, Score: 3, Record: 21
# Game: 568, Score: 3, Record: 21
# Game: 569, Score: 2, Record: 21
# Game: 570, Score: 0, Record: 21
# Game: 571, Score: 1, Record: 21
# Game: 572, Score: 1, Record: 21
# Game: 573, Score: 6, Record: 21
# Game: 574, Score: 1, Record: 21
# Game: 575, Score: 1, Record: 21
# Game: 576, Score: 1, Record: 21
# Game: 577, Score: 4, Record: 21
# Game: 578, Score: 5, Record: 21
# Game: 579, Score: 7, Record: 21
# Game: 580, Score: 3, Record: 21
# Game: 581, Score: 5, Record: 21
# Game: 582, Score: 1, Record: 21
# Game: 583, Score: 6, Record: 21
# Game: 584, Score: 3, Record: 21
# Game: 585, Score: 2, Record: 21
# Game: 586, Score: 8, Record: 21
# Game: 587, Score: 4, Record: 21
# Game: 588, Score: 4, Record: 21
# Game: 589, Score: 4, Record: 21
# Game: 590, Score: 8, Record: 21
# Game: 591, Score: 9, Record: 21
# Game: 592, Score: 1, Record: 21
# Game: 593, Score: 5, Record: 21
# Game: 594, Score: 4, Record: 21
# Game: 595, Score: 1, Record: 21
# Game: 596, Score: 1, Record: 21
# Game: 597, Score: 2, Record: 21
# Game: 598, Score: 5, Record: 21
# Game: 599, Score: 7, Record: 21
# Game: 600, Score: 2, Record: 21
# Game: 601, Score: 4, Record: 21
# Game: 602, Score: 9, Record: 21
# Game: 603, Score: 3, Record: 21
# Game: 604, Score: 6, Record: 21
# Game: 605, Score: 3, Record: 21
# Game: 606, Score: 7, Record: 21
# Game: 607, Score: 7, Record: 21
# Game: 608, Score: 10, Record: 21
# Game: 609, Score: 1, Record: 21
# Game: 610, Score: 7, Record: 21
# Game: 611, Score: 1, Record: 21
# Game: 612, Score: 5, Record: 21
# Game: 613, Score: 1, Record: 21
# Game: 614, Score: 1, Record: 21
# Game: 615, Score: 6, Record: 21
# Game: 616, Score: 5, Record: 21
# Game: 617, Score: 1, Record: 21
# Game: 618, Score: 9, Record: 21
# Game: 619, Score: 5, Record: 21
# Game: 620, Score: 3, Record: 21
# Game: 621, Score: 9, Record: 21
# Game: 622, Score: 13, Record: 21
# Game: 623, Score: 3, Record: 21
# Game: 624, Score: 4, Record: 21
# Game: 625, Score: 1, Record: 21
# Game: 626, Score: 1, Record: 21
# Game: 627, Score: 8, Record: 21
# Game: 628, Score: 1, Record: 21
# Game: 629, Score: 4, Record: 21
# Game: 630, Score: 1, Record: 21
# Game: 631, Score: 2, Record: 21
# Game: 632, Score: 5, Record: 21
# Game: 633, Score: 4, Record: 21
# Game: 634, Score: 8, Record: 21
# Game: 635, Score: 6, Record: 21
# Game: 636, Score: 10, Record: 21
# Game: 637, Score: 5, Record: 21
# Game: 638, Score: 6, Record: 21
# Game: 639, Score: 2, Record: 21
# Game: 640, Score: 6, Record: 21
# Game: 641, Score: 1, Record: 21
# Game: 642, Score: 2, Record: 21
# Game: 643, Score: 5, Record: 21
# Game: 644, Score: 2, Record: 21
# Game: 645, Score: 6, Record: 21
# Game: 646, Score: 9, Record: 21
# Game: 647, Score: 2, Record: 21
# Game: 648, Score: 4, Record: 21
# Game: 649, Score: 1, Record: 21
# Game: 650, Score: 4, Record: 21
# Game: 651, Score: 8, Record: 21
# Game: 652, Score: 2, Record: 21
# Game: 653, Score: 3, Record: 21
# Game: 654, Score: 3, Record: 21
# Game: 655, Score: 1, Record: 21
# Game: 656, Score: 4, Record: 21
# Game: 657, Score: 8, Record: 21
# Game: 658, Score: 2, Record: 21
# Game: 659, Score: 5, Record: 21
# Game: 660, Score: 2, Record: 21
# Game: 661, Score: 4, Record: 21
# Game: 662, Score: 3, Record: 21
# Game: 663, Score: 3, Record: 21
# Game: 664, Score: 3, Record: 21
# Game: 665, Score: 10, Record: 21
# Game: 666, Score: 3, Record: 21
# Game: 667, Score: 8, Record: 21
# Game: 668, Score: 3, Record: 21
# Game: 669, Score: 6, Record: 21
# Game: 670, Score: 1, Record: 21
# Game: 671, Score: 10, Record: 21
# Game: 672, Score: 1, Record: 21
# Game: 673, Score: 6, Record: 21
# Game: 674, Score: 3, Record: 21
# Game: 675, Score: 1, Record: 21
# Game: 676, Score: 3, Record: 21
# Game: 677, Score: 5, Record: 21
# Game: 678, Score: 4, Record: 21
# Game: 679, Score: 1, Record: 21
# Game: 680, Score: 1, Record: 21
# Game: 681, Score: 8, Record: 21
# Game: 682, Score: 7, Record: 21
# Game: 683, Score: 5, Record: 21
# Game: 684, Score: 10, Record: 21
# Game: 685, Score: 3, Record: 21
# Game: 686, Score: 0, Record: 21
# Game: 687, Score: 7, Record: 21
# Game: 688, Score: 16, Record: 21
# Game: 689, Score: 4, Record: 21
# Game: 690, Score: 4, Record: 21
# Game: 691, Score: 7, Record: 21
# Game: 692, Score: 1, Record: 21
# Game: 693, Score: 1, Record: 21
# Game: 694, Score: 1, Record: 21
# Game: 695, Score: 5, Record: 21
# Game: 696, Score: 3, Record: 21
# Game: 697, Score: 2, Record: 21
# Game: 698, Score: 0, Record: 21
# Game: 699, Score: 6, Record: 21
# Game: 700, Score: 5, Record: 21
# Game: 701, Score: 4, Record: 21
# Game: 702, Score: 3, Record: 21
# Game: 703, Score: 2, Record: 21
# Game: 704, Score: 5, Record: 21
# Game: 705, Score: 5, Record: 21
# Game: 706, Score: 18, Record: 21
# Game: 707, Score: 1, Record: 21
# Game: 708, Score: 11, Record: 21
# Game: 709, Score: 1, Record: 21
# Game: 710, Score: 10, Record: 21
# Game: 711, Score: 5, Record: 21
# Game: 712, Score: 7, Record: 21
# Game: 713, Score: 6, Record: 21
# Game: 714, Score: 6, Record: 21
# Game: 715, Score: 2, Record: 21
# Game: 716, Score: 1, Record: 21
# Game: 717, Score: 2, Record: 21
# Game: 718, Score: 1, Record: 21
# Game: 719, Score: 1, Record: 21
# Game: 720, Score: 7, Record: 21
# Game: 721, Score: 1, Record: 21
# Game: 722, Score: 1, Record: 21
# Game: 723, Score: 2, Record: 21
# Game: 724, Score: 3, Record: 21
# Game: 725, Score: 7, Record: 21
# Game: 726, Score: 10, Record: 21
# Game: 727, Score: 2, Record: 21
# Game: 728, Score: 2, Record: 21
# Game: 729, Score: 5, Record: 21
# Game: 730, Score: 3, Record: 21
# Game: 731, Score: 5, Record: 21
# Game: 732, Score: 3, Record: 21
# Game: 733, Score: 10, Record: 21
# Game: 734, Score: 5, Record: 21
# Game: 735, Score: 1, Record: 21
# Game: 736, Score: 4, Record: 21
# Game: 737, Score: 4, Record: 21
# Game: 738, Score: 2, Record: 21
# Game: 739, Score: 4, Record: 21
# Game: 740, Score: 2, Record: 21
# Game: 741, Score: 1, Record: 21
# Game: 742, Score: 1, Record: 21
# Game: 743, Score: 0, Record: 21
# Game: 744, Score: 8, Record: 21
# Game: 745, Score: 9, Record: 21
# Game: 746, Score: 2, Record: 21
# Game: 747, Score: 7, Record: 21
# Game: 748, Score: 1, Record: 21
# Game: 749, Score: 3, Record: 21
# Game: 750, Score: 1, Record: 21
# Game: 751, Score: 2, Record: 21
# Game: 752, Score: 1, Record: 21
# Game: 753, Score: 2, Record: 21
# Game: 754, Score: 7, Record: 21
# Game: 755, Score: 4, Record: 21
# Game: 756, Score: 0, Record: 21
# Game: 757, Score: 3, Record: 21
# Game: 758, Score: 2, Record: 21
# Game: 759, Score: 2, Record: 21
# Game: 760, Score: 2, Record: 21
# Game: 761, Score: 2, Record: 21
# Game: 762, Score: 5, Record: 21
# Game: 763, Score: 3, Record: 21
# Game: 764, Score: 7, Record: 21
# Game: 765, Score: 10, Record: 21
# Game: 766, Score: 11, Record: 21
# Game: 767, Score: 7, Record: 21
# Game: 768, Score: 0, Record: 21
# Game: 769, Score: 2, Record: 21
# Game: 770, Score: 2, Record: 21
# Game: 771, Score: 1, Record: 21
# Game: 772, Score: 1, Record: 21
# Game: 773, Score: 9, Record: 21
# Game: 774, Score: 4, Record: 21
# Game: 775, Score: 6, Record: 21
# Game: 776, Score: 2, Record: 21
# Game: 777, Score: 1, Record: 21
# Game: 778, Score: 4, Record: 21
# Game: 779, Score: 7, Record: 21
# Game: 780, Score: 6, Record: 21
# Game: 781, Score: 2, Record: 21
# Game: 782, Score: 5, Record: 21
# Game: 783, Score: 1, Record: 21
# Game: 784, Score: 3, Record: 21
# Game: 785, Score: 4, Record: 21
# Game: 786, Score: 7, Record: 21
# Game: 787, Score: 5, Record: 21
# Game: 788, Score: 2, Record: 21
# Game: 789, Score: 2, Record: 21
# Game: 790, Score: 4, Record: 21
# Game: 791, Score: 5, Record: 21
# Game: 792, Score: 3, Record: 21
# Game: 793, Score: 6, Record: 21
# Game: 794, Score: 3, Record: 21
# Game: 795, Score: 2, Record: 21
# Game: 796, Score: 8, Record: 21
# Game: 797, Score: 1, Record: 21
# Game: 798, Score: 4, Record: 21
# Game: 799, Score: 3, Record: 21
# Game: 800, Score: 4, Record: 21
# Game: 801, Score: 1, Record: 21
# Game: 802, Score: 3, Record: 21
# Game: 803, Score: 9, Record: 21
# Game: 804, Score: 10, Record: 21
# Game: 805, Score: 3, Record: 21
# Game: 806, Score: 3, Record: 21
# Game: 807, Score: 3, Record: 21
# Game: 808, Score: 4, Record: 21
# Game: 809, Score: 4, Record: 21
# Game: 810, Score: 6, Record: 21
# Game: 811, Score: 1, Record: 21
# Game: 812, Score: 1, Record: 21
# Game: 813, Score: 4, Record: 21
# Game: 814, Score: 5, Record: 21
# Game: 815, Score: 5, Record: 21
# Game: 816, Score: 8, Record: 21
# Game: 817, Score: 4, Record: 21
# Game: 818, Score: 3, Record: 21
# Game: 819, Score: 2, Record: 21
# Game: 820, Score: 2, Record: 21
# Game: 821, Score: 12, Record: 21
# Game: 822, Score: 2, Record: 21
# Game: 823, Score: 4, Record: 21
# Game: 824, Score: 9, Record: 21
# Game: 825, Score: 2, Record: 21
# Game: 826, Score: 2, Record: 21
# Game: 827, Score: 3, Record: 21
# Game: 828, Score: 3, Record: 21
# Game: 829, Score: 2, Record: 21
# Game: 830, Score: 15, Record: 21
# Game: 831, Score: 4, Record: 21
# Game: 832, Score: 2, Record: 21
# Game: 833, Score: 1, Record: 21
# Game: 834, Score: 5, Record: 21
# Game: 835, Score: 5, Record: 21
# Game: 836, Score: 3, Record: 21
# Game: 837, Score: 3, Record: 21
# Game: 838, Score: 7, Record: 21
# Game: 839, Score: 7, Record: 21
# Game: 840, Score: 1, Record: 21
# Game: 841, Score: 9, Record: 21
# Game: 842, Score: 1, Record: 21
# Game: 843, Score: 2, Record: 21
# Game: 844, Score: 13, Record: 21
# Game: 845, Score: 2, Record: 21
# Game: 846, Score: 10, Record: 21
# Game: 847, Score: 4, Record: 21
# Game: 848, Score: 7, Record: 21
# Game: 849, Score: 6, Record: 21
# Game: 850, Score: 4, Record: 21
# Game: 851, Score: 2, Record: 21
# Game: 852, Score: 1, Record: 21
# Game: 853, Score: 7, Record: 21
# Game: 854, Score: 1, Record: 21
# Game: 855, Score: 3, Record: 21
# Game: 856, Score: 1, Record: 21
# Game: 857, Score: 4, Record: 21
# Game: 858, Score: 5, Record: 21
# Game: 859, Score: 17, Record: 21
# Game: 860, Score: 6, Record: 21
# Game: 861, Score: 3, Record: 21
# Game: 862, Score: 1, Record: 21
# Game: 863, Score: 10, Record: 21
# Game: 864, Score: 1, Record: 21
# Game: 865, Score: 6, Record: 21
# Game: 866, Score: 2, Record: 21
# Game: 867, Score: 3, Record: 21
# Game: 868, Score: 9, Record: 21
# Game: 869, Score: 5, Record: 21
# Game: 870, Score: 3, Record: 21
# Game: 871, Score: 4, Record: 21
# Game: 872, Score: 9, Record: 21
# Game: 873, Score: 4, Record: 21
# Game: 874, Score: 4, Record: 21
# Game: 875, Score: 11, Record: 21
# Game: 876, Score: 1, Record: 21
# Game: 877, Score: 4, Record: 21
# Game: 878, Score: 8, Record: 21
# Game: 879, Score: 1, Record: 21
# Game: 880, Score: 3, Record: 21
# Game: 881, Score: 5, Record: 21
# Game: 882, Score: 7, Record: 21
# Game: 883, Score: 5, Record: 21
# Game: 884, Score: 1, Record: 21
# Game: 885, Score: 5, Record: 21
# Game: 886, Score: 2, Record: 21
# Game: 887, Score: 4, Record: 21
# Game: 888, Score: 4, Record: 21
# Game: 889, Score: 3, Record: 21
# Game: 890, Score: 4, Record: 21
# Game: 891, Score: 2, Record: 21
# Game: 892, Score: 2, Record: 21
# Game: 893, Score: 1, Record: 21
# Game: 894, Score: 2, Record: 21
# Game: 895, Score: 5, Record: 21
# Game: 896, Score: 0, Record: 21
# Game: 897, Score: 2, Record: 21
# Game: 898, Score: 1, Record: 21
# Game: 899, Score: 4, Record: 21
# Game: 900, Score: 7, Record: 21
# Game: 901, Score: 5, Record: 21
# Game: 902, Score: 3, Record: 21
# Game: 903, Score: 2, Record: 21
# Game: 904, Score: 3, Record: 21
# Game: 905, Score: 2, Record: 21
# Game: 906, Score: 5, Record: 21
# Game: 907, Score: 4, Record: 21
# Game: 908, Score: 7, Record: 21
# Game: 909, Score: 1, Record: 21
# Game: 910, Score: 1, Record: 21
# Game: 911, Score: 1, Record: 21
# Game: 912, Score: 9, Record: 21
# Game: 913, Score: 1, Record: 21
# Game: 914, Score: 10, Record: 21
# Game: 915, Score: 3, Record: 21
# Game: 916, Score: 0, Record: 21
# Game: 917, Score: 13, Record: 21
# Game: 918, Score: 2, Record: 21
# Game: 919, Score: 7, Record: 21
# Game: 920, Score: 1, Record: 21
# Game: 921, Score: 5, Record: 21
# Game: 922, Score: 8, Record: 21
# Game: 923, Score: 4, Record: 21
# Game: 924, Score: 4, Record: 21
# Game: 925, Score: 8, Record: 21
# Game: 926, Score: 1, Record: 21
# Game: 927, Score: 7, Record: 21
# Game: 928, Score: 1, Record: 21
# Game: 929, Score: 3, Record: 21
# Game: 930, Score: 2, Record: 21
# Game: 931, Score: 5, Record: 21
# Game: 932, Score: 7, Record: 21
# Game: 933, Score: 1, Record: 21
# Game: 934, Score: 4, Record: 21
# Game: 935, Score: 5, Record: 21
# Game: 936, Score: 2, Record: 21
# Game: 937, Score: 10, Record: 21
# Game: 938, Score: 5, Record: 21
# Game: 939, Score: 1, Record: 21
# Game: 940, Score: 2, Record: 21
# Game: 941, Score: 5, Record: 21
# Game: 942, Score: 4, Record: 21
# Game: 943, Score: 2, Record: 21
# Game: 944, Score: 8, Record: 21
# Game: 945, Score: 4, Record: 21
# Game: 946, Score: 5, Record: 21
# Game: 947, Score: 8, Record: 21
# Game: 948, Score: 3, Record: 21
# Game: 949, Score: 7, Record: 21
# Game: 950, Score: 3, Record: 21
# Game: 951, Score: 1, Record: 21
# Game: 952, Score: 3, Record: 21
# Game: 953, Score: 4, Record: 21
# Game: 954, Score: 8, Record: 21
# Game: 955, Score: 1, Record: 21
# Game: 956, Score: 5, Record: 21
# Game: 957, Score: 3, Record: 21
# Game: 958, Score: 5, Record: 21
# Game: 959, Score: 6, Record: 21
# Game: 960, Score: 2, Record: 21
# Game: 961, Score: 4, Record: 21
# Game: 962, Score: 6, Record: 21
# Game: 963, Score: 8, Record: 21
# Game: 964, Score: 1, Record: 21
# Game: 965, Score: 10, Record: 21
# Game: 966, Score: 1, Record: 21
# Game: 967, Score: 3, Record: 21
# Game: 968, Score: 4, Record: 21
# Game: 969, Score: 4, Record: 21
# Game: 970, Score: 1, Record: 21
# Game: 971, Score: 4, Record: 21
# Game: 972, Score: 15, Record: 21
# Game: 973, Score: 4, Record: 21
# Game: 974, Score: 3, Record: 21
# Game: 975, Score: 8, Record: 21
# Game: 976, Score: 4, Record: 21
# Game: 977, Score: 8, Record: 21
# Game: 978, Score: 1, Record: 21
# Game: 979, Score: 1, Record: 21
# Game: 980, Score: 3, Record: 21
# Game: 981, Score: 4, Record: 21
# Game: 982, Score: 2, Record: 21
# Game: 983, Score: 2, Record: 21
# Game: 984, Score: 8, Record: 21
# Game: 985, Score: 2, Record: 21
# Game: 986, Score: 3, Record: 21
# Game: 987, Score: 9, Record: 21
# Game: 988, Score: 1, Record: 21
# Game: 989, Score: 5, Record: 21
# Game: 990, Score: 1, Record: 21
# Game: 991, Score: 1, Record: 21
# Game: 992, Score: 6, Record: 21
# Game: 993, Score: 3, Record: 21
# Game: 994, Score: 2, Record: 21
# Game: 995, Score: 1, Record: 21
# Game: 996, Score: 9, Record: 21
# Game: 997, Score: 4, Record: 21
# Game: 998, Score: 9, Record: 21
# Game: 999, Score: 4, Record: 21
# Game: 1000, Score: 4, Record: 21
# Game: 1001, Score: 7, Record: 21
# Game: 1002, Score: 1, Record: 21
# Game: 1003, Score: 2, Record: 21
# Game: 1004, Score: 3, Record: 21
# Game: 1005, Score: 3, Record: 21
# Game: 1006, Score: 1, Record: 21
# Game: 1007, Score: 1, Record: 21
# Game: 1008, Score: 2, Record: 21
# Game: 1009, Score: 3, Record: 21
# Game: 1010, Score: 6, Record: 21
# Game: 1011, Score: 6, Record: 21
# Game: 1012, Score: 4, Record: 21
# Game: 1013, Score: 2, Record: 21
# Game: 1014, Score: 2, Record: 21
# Game: 1015, Score: 0, Record: 21
# Game: 1016, Score: 10, Record: 21
# Game: 1017, Score: 1, Record: 21
# Game: 1018, Score: 9, Record: 21
# Game: 1019, Score: 10, Record: 21
# Game: 1020, Score: 1, Record: 21
# Game: 1021, Score: 3, Record: 21
# Game: 1022, Score: 8, Record: 21
# Game: 1023, Score: 9, Record: 21
# Game: 1024, Score: 1, Record: 21
# Game: 1025, Score: 4, Record: 21
# Game: 1026, Score: 5, Record: 21
# Game: 1027, Score: 1, Record: 21
# Game: 1028, Score: 3, Record: 21
# Game: 1029, Score: 10, Record: 21
# Game: 1030, Score: 4, Record: 21
# Game: 1031, Score: 1, Record: 21
# Game: 1032, Score: 2, Record: 21
# Game: 1033, Score: 0, Record: 21
# Game: 1034, Score: 3, Record: 21
# Game: 1035, Score: 5, Record: 21
# Game: 1036, Score: 7, Record: 21
# Game: 1037, Score: 1, Record: 21
# Game: 1038, Score: 2, Record: 21
# Game: 1039, Score: 6, Record: 21
# Game: 1040, Score: 2, Record: 21
# Game: 1041, Score: 9, Record: 21
# Game: 1042, Score: 4, Record: 21
# Game: 1043, Score: 1, Record: 21
# Game: 1044, Score: 1, Record: 21
# Game: 1045, Score: 7, Record: 21
# Game: 1046, Score: 1, Record: 21
# Game: 1047, Score: 2, Record: 21
# Game: 1048, Score: 10, Record: 21
# Game: 1049, Score: 8, Record: 21
# Game: 1050, Score: 5, Record: 21
# Game: 1051, Score: 1, Record: 21
# Game: 1052, Score: 1, Record: 21
# Game: 1053, Score: 5, Record: 21
# Game: 1054, Score: 8, Record: 21
# Game: 1055, Score: 2, Record: 21
# Game: 1056, Score: 4, Record: 21
# Game: 1057, Score: 6, Record: 21
# Game: 1058, Score: 3, Record: 21
# Game: 1059, Score: 0, Record: 21
# Game: 1060, Score: 6, Record: 21
# Game: 1061, Score: 6, Record: 21
# Game: 1062, Score: 3, Record: 21
# Game: 1063, Score: 2, Record: 21
# Game: 1064, Score: 1, Record: 21
# Game: 1065, Score: 4, Record: 21
# Game: 1066, Score: 8, Record: 21
# Game: 1067, Score: 13, Record: 21
# Game: 1068, Score: 1, Record: 21
# Game: 1069, Score: 0, Record: 21
# Game: 1070, Score: 3, Record: 21
# Game: 1071, Score: 0, Record: 21
# Game: 1072, Score: 22, Record: 22
# Game: 1073, Score: 3, Record: 22
# Game: 1074, Score: 1, Record: 22
# Game: 1075, Score: 4, Record: 22
# Game: 1076, Score: 6, Record: 22
# Game: 1077, Score: 6, Record: 22
# Game: 1078, Score: 1, Record: 22
# Game: 1079, Score: 3, Record: 22
# Game: 1080, Score: 2, Record: 22
# Game: 1081, Score: 3, Record: 22
# Game: 1082, Score: 8, Record: 22
# Game: 1083, Score: 4, Record: 22
# Game: 1084, Score: 7, Record: 22
# Game: 1085, Score: 4, Record: 22
# Game: 1086, Score: 3, Record: 22
# Game: 1087, Score: 2, Record: 22
# Game: 1088, Score: 5, Record: 22
# Game: 1089, Score: 2, Record: 22
# Game: 1090, Score: 1, Record: 22
# Game: 1091, Score: 2, Record: 22
# Game: 1092, Score: 2, Record: 22
# Game: 1093, Score: 7, Record: 22
# Game: 1094, Score: 2, Record: 22
# Game: 1095, Score: 5, Record: 22
# Game: 1096, Score: 7, Record: 22
# Game: 1097, Score: 4, Record: 22
# Game: 1098, Score: 5, Record: 22
# Game: 1099, Score: 1, Record: 22
# Game: 1100, Score: 20, Record: 22
# Game: 1101, Score: 2, Record: 22
# Game: 1102, Score: 0, Record: 22
# Game: 1103, Score: 6, Record: 22
# Game: 1104, Score: 3, Record: 22
# Game: 1105, Score: 4, Record: 22
# Game: 1106, Score: 2, Record: 22
# Game: 1107, Score: 3, Record: 22
# Game: 1108, Score: 8, Record: 22
# Game: 1109, Score: 9, Record: 22
# Game: 1110, Score: 1, Record: 22
# Game: 1111, Score: 4, Record: 22
# Game: 1112, Score: 2, Record: 22
# Game: 1113, Score: 0, Record: 22
# Game: 1114, Score: 1, Record: 22
# Game: 1115, Score: 1, Record: 22
# Game: 1116, Score: 1, Record: 22
# Game: 1117, Score: 9, Record: 22
# Game: 1118, Score: 13, Record: 22
# Game: 1119, Score: 3, Record: 22
# Game: 1120, Score: 4, Record: 22
# Game: 1121, Score: 1, Record: 22
# Game: 1122, Score: 1, Record: 22
# Game: 1123, Score: 1, Record: 22
# Game: 1124, Score: 3, Record: 22
# Game: 1125, Score: 13, Record: 22
# Game: 1126, Score: 5, Record: 22
# Game: 1127, Score: 4, Record: 22
# Game: 1128, Score: 6, Record: 22
# Game: 1129, Score: 1, Record: 22
# Game: 1130, Score: 7, Record: 22
# Game: 1131, Score: 4, Record: 22
# Game: 1132, Score: 1, Record: 22
# Game: 1133, Score: 11, Record: 22
# Game: 1134, Score: 4, Record: 22
# Game: 1135, Score: 12, Record: 22
# Game: 1136, Score: 1, Record: 22
# Game: 1137, Score: 4, Record: 22
# Game: 1138, Score: 1, Record: 22
# Game: 1139, Score: 4, Record: 22
# Game: 1140, Score: 1, Record: 22
# Game: 1141, Score: 6, Record: 22
# Game: 1142, Score: 3, Record: 22
# Game: 1143, Score: 4, Record: 22
# Game: 1144, Score: 4, Record: 22
# Game: 1145, Score: 5, Record: 22
# Game: 1146, Score: 4, Record: 22
# Game: 1147, Score: 5, Record: 22
# Game: 1148, Score: 4, Record: 22
# Game: 1149, Score: 2, Record: 22
# Game: 1150, Score: 2, Record: 22
# Game: 1151, Score: 7, Record: 22
# Game: 1152, Score: 1, Record: 22
# Game: 1153, Score: 1, Record: 22
# Game: 1154, Score: 3, Record: 22
# Game: 1155, Score: 4, Record: 22
# Game: 1156, Score: 4, Record: 22
# Game: 1157, Score: 1, Record: 22
# Game: 1158, Score: 6, Record: 22
# Game: 1159, Score: 4, Record: 22
# Game: 1160, Score: 3, Record: 22
# Game: 1161, Score: 1, Record: 22
# Game: 1162, Score: 10, Record: 22
# Game: 1163, Score: 6, Record: 22
# Game: 1164, Score: 10, Record: 22
# Game: 1165, Score: 6, Record: 22
# Game: 1166, Score: 3, Record: 22
# Game: 1167, Score: 1, Record: 22
# Game: 1168, Score: 2, Record: 22
# Game: 1169, Score: 6, Record: 22
# Game: 1170, Score: 2, Record: 22
# Game: 1171, Score: 6, Record: 22
# Game: 1172, Score: 3, Record: 22
# Game: 1173, Score: 5, Record: 22
# Game: 1174, Score: 4, Record: 22
# Game: 1175, Score: 1, Record: 22
# Game: 1176, Score: 3, Record: 22
# Game: 1177, Score: 6, Record: 22
# Game: 1178, Score: 6, Record: 22
# Game: 1179, Score: 20, Record: 22
# Game: 1180, Score: 5, Record: 22
# Game: 1181, Score: 5, Record: 22
# Game: 1182, Score: 8, Record: 22
# Game: 1183, Score: 0, Record: 22
# Game: 1184, Score: 7, Record: 22
# Game: 1185, Score: 7, Record: 22
# Game: 1186, Score: 13, Record: 22
# Game: 1187, Score: 2, Record: 22
# Game: 1188, Score: 1, Record: 22
# Game: 1189, Score: 3, Record: 22
# Game: 1190, Score: 4, Record: 22
# Game: 1191, Score: 3, Record: 22
# Game: 1192, Score: 5, Record: 22
# Game: 1193, Score: 4, Record: 22
# Game: 1194, Score: 7, Record: 22
# Game: 1195, Score: 5, Record: 22
# Game: 1196, Score: 3, Record: 22
# Game: 1197, Score: 3, Record: 22
# Game: 1198, Score: 11, Record: 22
# Game: 1199, Score: 12, Record: 22
# Game: 1200, Score: 4, Record: 22
# Game: 1201, Score: 3, Record: 22
# Game: 1202, Score: 1, Record: 22
# Game: 1203, Score: 6, Record: 22
# Game: 1204, Score: 2, Record: 22
# Game: 1205, Score: 11, Record: 22
# Game: 1206, Score: 2, Record: 22
# Game: 1207, Score: 2, Record: 22
# Game: 1208, Score: 4, Record: 22
# Game: 1209, Score: 6, Record: 22
# Game: 1210, Score: 3, Record: 22
# Game: 1211, Score: 10, Record: 22
# Game: 1212, Score: 2, Record: 22
# Game: 1213, Score: 7, Record: 22
# Game: 1214, Score: 1, Record: 22
# Game: 1215, Score: 9, Record: 22
# Game: 1216, Score: 1, Record: 22
# Game: 1217, Score: 3, Record: 22
# Game: 1218, Score: 16, Record: 22
# Game: 1219, Score: 2, Record: 22
# Game: 1220, Score: 13, Record: 22
# Game: 1221, Score: 11, Record: 22
# Game: 1222, Score: 8, Record: 22
# Game: 1223, Score: 7, Record: 22
# Game: 1224, Score: 4, Record: 22
# Game: 1225, Score: 4, Record: 22
# Game: 1226, Score: 1, Record: 22
# Game: 1227, Score: 7, Record: 22
# Game: 1228, Score: 3, Record: 22
# Game: 1229, Score: 4, Record: 22
# Game: 1230, Score: 1, Record: 22
# Game: 1231, Score: 5, Record: 22
# Game: 1232, Score: 4, Record: 22
# Game: 1233, Score: 2, Record: 22
# Game: 1234, Score: 13, Record: 22
# Game: 1235, Score: 0, Record: 22
# Game: 1236, Score: 7, Record: 22
# Game: 1237, Score: 5, Record: 22
# Game: 1238, Score: 2, Record: 22
# Game: 1239, Score: 1, Record: 22
# Game: 1240, Score: 1, Record: 22
# Game: 1241, Score: 4, Record: 22
# Game: 1242, Score: 3, Record: 22
# Game: 1243, Score: 10, Record: 22
# Game: 1244, Score: 12, Record: 22
# Game: 1245, Score: 3, Record: 22
# Game: 1246, Score: 4, Record: 22
# Game: 1247, Score: 1, Record: 22
# Game: 1248, Score: 11, Record: 22
# Game: 1249, Score: 3, Record: 22
# Game: 1250, Score: 2, Record: 22
# Game: 1251, Score: 1, Record: 22
# Game: 1252, Score: 1, Record: 22
# Game: 1253, Score: 1, Record: 22
# Game: 1254, Score: 4, Record: 22
# Game: 1255, Score: 4, Record: 22
# Game: 1256, Score: 6, Record: 22
# Game: 1257, Score: 18, Record: 22
# Game: 1258, Score: 8, Record: 22
# Game: 1259, Score: 4, Record: 22
# Game: 1260, Score: 7, Record: 22
# Game: 1261, Score: 5, Record: 22
# Game: 1262, Score: 6, Record: 22
# Game: 1263, Score: 3, Record: 22
# Game: 1264, Score: 2, Record: 22
# Game: 1265, Score: 7, Record: 22
# Game: 1266, Score: 0, Record: 22
# Game: 1267, Score: 14, Record: 22
# Game: 1268, Score: 6, Record: 22
# Game: 1269, Score: 14, Record: 22
# Game: 1270, Score: 1, Record: 22
# Game: 1271, Score: 2, Record: 22
# Game: 1272, Score: 3, Record: 22
# Game: 1273, Score: 1, Record: 22
# Game: 1274, Score: 2, Record: 22
# Game: 1275, Score: 4, Record: 22
# Game: 1276, Score: 6, Record: 22
# Game: 1277, Score: 4, Record: 22
# Game: 1278, Score: 3, Record: 22
# Game: 1279, Score: 1, Record: 22
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 335
#     331             print(f'Game: {agent.n_games}, Score: {score}, Record: {record}')
#     334 if __name__ == '__main__':
# --> 335     train()
#
# Cell In[1], line 312, in train()
#     310 state_old = game.get_state()
#     311 final_move = agent.get_action(state_old)
# --> 312 reward, done, score = game.play_step(final_move)
#     313 state_new = game.get_state()
#     315 agent.train_short_memory(state_old, final_move, reward, state_new, done)
#
# Cell In[1], line 80, in SnakeGameAI.play_step(self, action)
#      78 else:
#      79     self.snake.pop()
# ---> 80 self._update_ui()
#      81 self.clock.tick(SPEED)
#      82 return reward, game_over, self.score
#
# Cell In[1], line 94, in SnakeGameAI._update_ui(self)
#      93 def _update_ui(self):
# ---> 94     self.display.fill(pygame.Color('black'))
#      95     for pt in self.snake:
#      96         pygame.draw.rect(self.display, pygame.Color('green'), pygame.Rect(pt.x, pt.y, BLOCK_SIZE, BLOCK_SIZE))
#
# error: display Surface quit
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
